# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/topics/GraphQL?page='
final_link=[]
for num in range( 1,8):
    final_link.append(base_url+str(num))
GraphQL_dict = {}
GraphQL_lst = []
SrNo=1
for urls in final_link:
    raw_data = requests.get(urls).text
    soup = BeautifulSoup(raw_data,'lxml')
    all_div=soup.find_all('article', class_="border rounded color-shadow-small color-bg-subtle my-4")
    for item in all_div:
        if(SrNo>200):
            continue
        else:
            repository_name=item.find('a',class_='text-bold wb-break-word').text
            repository_name=repository_name.strip()
            user_name=item.find("h3",class_="f3 color-fg-muted text-normal lh-condensed").text
            user_name=user_name.strip().split("/")[0].strip()
            star=item.find('span',class_='Counter js-social-count').text
            product_link=item.find('a',class_='text-bold wb-break-word')['href']
            product_url = base_url+product_link
            GraphQL_dict = {
                'Sr No':SrNo,
                'User Name':user_name,
                'Repository_Name':repository_name,
                'Star':star,
                'Product URL':product_url
        
                 }
        GraphQL_lst.append(GraphQL_dict)
        SrNo+=1

# %%
GraphQL_lst
# Out:
# [{'Sr No': 1,
#   'User Name': 'gatsbyjs',
#   'Repository_Name': 'gatsby',
#   'Star': '53.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/gatsbyjs/gatsby'},
#  {'Sr No': 2,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/strapi/strapi'},
#  {'Sr No': 3,
#   'User Name': 'hoppscotch',
#   'Repository_Name': 'hoppscotch',
#   'Star': '44.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hoppscotch/hoppscotch'},
#  {'Sr No': 4,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prettier/prettier'},
#  {'Sr No': 5,
#   'User Name': 'TanStack',
#   'Repository_Name': 'query',
#   'Star': '28.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/TanStack/query'},
#  {'Sr No': 6,
#   'User Name': 'hasura',
#   'Repository_Name': 'graphql-engine',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hasura/graphql-engine'},
#  {'Sr No': 7,
#   'User Name': 'Kong',
#   'Repository_Name': 'insomnia',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/Kong/insomnia'},
#  {'Sr No': 8,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 9,
#   'User Name': 'marmelab',
#   'Repository_Name': 'react-admin',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/marmelab/react-admin'},
#  {'Sr No': 10,
#   'User Name': 'parse-community',
#   'Repository_Name': 'parse-server',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/parse-community/parse-server'},
#  {'Sr No': 11,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphql-js',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphql-js'},
#  {'Sr No': 12,
#   'User Name': 'dgraph-io',
#   'Repository_Name': 'dgraph',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dgraph-io/dgraph'},
#  {'Sr No': 13,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-client',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-client'},
#  {'Sr No': 14,
#   'User Name': 'pubkey',
#   'Repository_Name': 'rxdb',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/pubkey/rxdb'},
#  {'Sr No': 15,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma1',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prisma/prisma1'},
#  {'Sr No': 16,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/directus/directus'},
#  {'Sr No': 17,
#   'User Name': 'saleor',
#   'Repository_Name': 'saleor',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/saleor/saleor'},
#  {'Sr No': 18,
#   'User Name': 'redwoodjs',
#   'Repository_Name': 'redwood',
#   'Star': '14.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/redwoodjs/redwood'},
#  {'Sr No': 19,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphiql',
#   'Star': '13.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphiql'},
#  {'Sr No': 20,
#   'User Name': 'chentsulin',
#   'Repository_Name': 'awesome-graphql',
#   'Star': '13.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/chentsulin/awesome-graphql'},
#  {'Sr No': 21,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-server',
#   'Star': '12.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-server'},
#  {'Sr No': 22,
#   'User Name': 'spree',
#   'Repository_Name': 'spree',
#   'Star': '11.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/spree/spree'},
#  {'Sr No': 23,
#   'User Name': 'reactioncommerce',
#   'Repository_Name': 'reaction',
#   'Star': '11.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/reactioncommerce/reaction'},
#  {'Sr No': 24,
#   'User Name': 'graphql',
#   'Repository_Name': 'dataloader',
#   'Star': '11.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/dataloader'},
#  {'Sr No': 25,
#   'User Name': 'graphile',
#   'Repository_Name': 'postgraphile',
#   'Star': '11.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphile/postgraphile'},
#  {'Sr No': 26,
#   'User Name': 'withspectrum',
#   'Repository_Name': 'spectrum',
#   'Star': '10.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/withspectrum/spectrum'},
#  {'Sr No': 27,
#   'User Name': 'dotansimha',
#   'Repository_Name': 'graphql-code-generator',
#   'Star': '8.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dotansimha/graphql-code-generator'},
#  {'Sr No': 28,
#   'User Name': 'graphql-go',
#   'Repository_Name': 'graphql',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql-go/graphql'},
#  {'Sr No': 29,
#   'User Name': 'apex',
#   'Repository_Name': 'up',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apex/up'},
#  {'Sr No': 30,
#   'User Name': 'devhubapp',
#   'Repository_Name': 'devhub',
#   'Star': '8.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/devhubapp/devhub'},
#  {'Sr No': 31,
#   'User Name': 'gatsbyjs',
#   'Repository_Name': 'gatsby',
#   'Star': '53.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/gatsbyjs/gatsby'},
#  {'Sr No': 32,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/strapi/strapi'},
#  {'Sr No': 33,
#   'User Name': 'hoppscotch',
#   'Repository_Name': 'hoppscotch',
#   'Star': '44.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hoppscotch/hoppscotch'},
#  {'Sr No': 34,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prettier/prettier'},
#  {'Sr No': 35,
#   'User Name': 'TanStack',
#   'Repository_Name': 'query',
#   'Star': '28.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/TanStack/query'},
#  {'Sr No': 36,
#   'User Name': 'hasura',
#   'Repository_Name': 'graphql-engine',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hasura/graphql-engine'},
#  {'Sr No': 37,
#   'User Name': 'Kong',
#   'Repository_Name': 'insomnia',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/Kong/insomnia'},
#  {'Sr No': 38,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 39,
#   'User Name': 'marmelab',
#   'Repository_Name': 'react-admin',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/marmelab/react-admin'},
#  {'Sr No': 40,
#   'User Name': 'parse-community',
#   'Repository_Name': 'parse-server',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/parse-community/parse-server'},
#  {'Sr No': 41,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphql-js',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphql-js'},
#  {'Sr No': 42,
#   'User Name': 'dgraph-io',
#   'Repository_Name': 'dgraph',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dgraph-io/dgraph'},
#  {'Sr No': 43,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-client',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-client'},
#  {'Sr No': 44,
#   'User Name': 'pubkey',
#   'Repository_Name': 'rxdb',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/pubkey/rxdb'},
#  {'Sr No': 45,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma1',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prisma/prisma1'},
#  {'Sr No': 46,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/directus/directus'},
#  {'Sr No': 47,
#   'User Name': 'saleor',
#   'Repository_Name': 'saleor',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/saleor/saleor'},
#  {'Sr No': 48,
#   'User Name': 'redwoodjs',
#   'Repository_Name': 'redwood',
#   'Star': '14.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/redwoodjs/redwood'},
#  {'Sr No': 49,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphiql',
#   'Star': '13.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphiql'},
#  {'Sr No': 50,
#   'User Name': 'chentsulin',
#   'Repository_Name': 'awesome-graphql',
#   'Star': '13.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/chentsulin/awesome-graphql'},
#  {'Sr No': 51,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-server',
#   'Star': '12.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-server'},
#  {'Sr No': 52,
#   'User Name': 'spree',
#   'Repository_Name': 'spree',
#   'Star': '11.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/spree/spree'},
#  {'Sr No': 53,
#   'User Name': 'reactioncommerce',
#   'Repository_Name': 'reaction',
#   'Star': '11.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/reactioncommerce/reaction'},
#  {'Sr No': 54,
#   'User Name': 'graphql',
#   'Repository_Name': 'dataloader',
#   'Star': '11.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/dataloader'},
#  {'Sr No': 55,
#   'User Name': 'graphile',
#   'Repository_Name': 'postgraphile',
#   'Star': '11.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphile/postgraphile'},
#  {'Sr No': 56,
#   'User Name': 'withspectrum',
#   'Repository_Name': 'spectrum',
#   'Star': '10.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/withspectrum/spectrum'},
#  {'Sr No': 57,
#   'User Name': 'dotansimha',
#   'Repository_Name': 'graphql-code-generator',
#   'Star': '8.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dotansimha/graphql-code-generator'},
#  {'Sr No': 58,
#   'User Name': 'graphql-go',
#   'Repository_Name': 'graphql',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql-go/graphql'},
#  {'Sr No': 59,
#   'User Name': 'apex',
#   'Repository_Name': 'up',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apex/up'},
#  {'Sr No': 60,
#   'User Name': 'devhubapp',
#   'Repository_Name': 'devhub',
#   'Star': '8.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/devhubapp/devhub'},
#  {'Sr No': 61,
#   'User Name': 'gatsbyjs',
#   'Repository_Name': 'gatsby',
#   'Star': '53.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/gatsbyjs/gatsby'},
#  {'Sr No': 62,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/strapi/strapi'},
#  {'Sr No': 63,
#   'User Name': 'hoppscotch',
#   'Repository_Name': 'hoppscotch',
#   'Star': '44.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hoppscotch/hoppscotch'},
#  {'Sr No': 64,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prettier/prettier'},
#  {'Sr No': 65,
#   'User Name': 'TanStack',
#   'Repository_Name': 'query',
#   'Star': '28.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/TanStack/query'},
#  {'Sr No': 66,
#   'User Name': 'hasura',
#   'Repository_Name': 'graphql-engine',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hasura/graphql-engine'},
#  {'Sr No': 67,
#   'User Name': 'Kong',
#   'Repository_Name': 'insomnia',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/Kong/insomnia'},
#  {'Sr No': 68,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 69,
#   'User Name': 'marmelab',
#   'Repository_Name': 'react-admin',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/marmelab/react-admin'},
#  {'Sr No': 70,
#   'User Name': 'parse-community',
#   'Repository_Name': 'parse-server',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/parse-community/parse-server'},
#  {'Sr No': 71,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphql-js',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphql-js'},
#  {'Sr No': 72,
#   'User Name': 'dgraph-io',
#   'Repository_Name': 'dgraph',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dgraph-io/dgraph'},
#  {'Sr No': 73,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-client',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-client'},
#  {'Sr No': 74,
#   'User Name': 'pubkey',
#   'Repository_Name': 'rxdb',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/pubkey/rxdb'},
#  {'Sr No': 75,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma1',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prisma/prisma1'},
#  {'Sr No': 76,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/directus/directus'},
#  {'Sr No': 77,
#   'User Name': 'saleor',
#   'Repository_Name': 'saleor',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/saleor/saleor'},
#  {'Sr No': 78,
#   'User Name': 'redwoodjs',
#   'Repository_Name': 'redwood',
#   'Star': '14.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/redwoodjs/redwood'},
#  {'Sr No': 79,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphiql',
#   'Star': '13.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphiql'},
#  {'Sr No': 80,
#   'User Name': 'chentsulin',
#   'Repository_Name': 'awesome-graphql',
#   'Star': '13.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/chentsulin/awesome-graphql'},
#  {'Sr No': 81,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-server',
#   'Star': '12.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-server'},
#  {'Sr No': 82,
#   'User Name': 'spree',
#   'Repository_Name': 'spree',
#   'Star': '11.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/spree/spree'},
#  {'Sr No': 83,
#   'User Name': 'reactioncommerce',
#   'Repository_Name': 'reaction',
#   'Star': '11.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/reactioncommerce/reaction'},
#  {'Sr No': 84,
#   'User Name': 'graphql',
#   'Repository_Name': 'dataloader',
#   'Star': '11.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/dataloader'},
#  {'Sr No': 85,
#   'User Name': 'graphile',
#   'Repository_Name': 'postgraphile',
#   'Star': '11.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphile/postgraphile'},
#  {'Sr No': 86,
#   'User Name': 'withspectrum',
#   'Repository_Name': 'spectrum',
#   'Star': '10.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/withspectrum/spectrum'},
#  {'Sr No': 87,
#   'User Name': 'dotansimha',
#   'Repository_Name': 'graphql-code-generator',
#   'Star': '8.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dotansimha/graphql-code-generator'},
#  {'Sr No': 88,
#   'User Name': 'graphql-go',
#   'Repository_Name': 'graphql',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql-go/graphql'},
#  {'Sr No': 89,
#   'User Name': 'apex',
#   'Repository_Name': 'up',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apex/up'},
#  {'Sr No': 90,
#   'User Name': 'devhubapp',
#   'Repository_Name': 'devhub',
#   'Star': '8.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/devhubapp/devhub'},
#  {'Sr No': 91,
#   'User Name': 'gatsbyjs',
#   'Repository_Name': 'gatsby',
#   'Star': '53.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/gatsbyjs/gatsby'},
#  {'Sr No': 92,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/strapi/strapi'},
#  {'Sr No': 93,
#   'User Name': 'hoppscotch',
#   'Repository_Name': 'hoppscotch',
#   'Star': '44.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hoppscotch/hoppscotch'},
#  {'Sr No': 94,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prettier/prettier'},
#  {'Sr No': 95,
#   'User Name': 'TanStack',
#   'Repository_Name': 'query',
#   'Star': '28.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/TanStack/query'},
#  {'Sr No': 96,
#   'User Name': 'hasura',
#   'Repository_Name': 'graphql-engine',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hasura/graphql-engine'},
#  {'Sr No': 97,
#   'User Name': 'Kong',
#   'Repository_Name': 'insomnia',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/Kong/insomnia'},
#  {'Sr No': 98,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 99,
#   'User Name': 'marmelab',
#   'Repository_Name': 'react-admin',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/marmelab/react-admin'},
#  {'Sr No': 100,
#   'User Name': 'parse-community',
#   'Repository_Name': 'parse-server',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/parse-community/parse-server'},
#  {'Sr No': 101,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphql-js',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphql-js'},
#  {'Sr No': 102,
#   'User Name': 'dgraph-io',
#   'Repository_Name': 'dgraph',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dgraph-io/dgraph'},
#  {'Sr No': 103,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-client',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-client'},
#  {'Sr No': 104,
#   'User Name': 'pubkey',
#   'Repository_Name': 'rxdb',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/pubkey/rxdb'},
#  {'Sr No': 105,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma1',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prisma/prisma1'},
#  {'Sr No': 106,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/directus/directus'},
#  {'Sr No': 107,
#   'User Name': 'saleor',
#   'Repository_Name': 'saleor',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/saleor/saleor'},
#  {'Sr No': 108,
#   'User Name': 'redwoodjs',
#   'Repository_Name': 'redwood',
#   'Star': '14.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/redwoodjs/redwood'},
#  {'Sr No': 109,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphiql',
#   'Star': '13.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphiql'},
#  {'Sr No': 110,
#   'User Name': 'chentsulin',
#   'Repository_Name': 'awesome-graphql',
#   'Star': '13.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/chentsulin/awesome-graphql'},
#  {'Sr No': 111,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-server',
#   'Star': '12.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-server'},
#  {'Sr No': 112,
#   'User Name': 'spree',
#   'Repository_Name': 'spree',
#   'Star': '11.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/spree/spree'},
#  {'Sr No': 113,
#   'User Name': 'reactioncommerce',
#   'Repository_Name': 'reaction',
#   'Star': '11.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/reactioncommerce/reaction'},
#  {'Sr No': 114,
#   'User Name': 'graphql',
#   'Repository_Name': 'dataloader',
#   'Star': '11.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/dataloader'},
#  {'Sr No': 115,
#   'User Name': 'graphile',
#   'Repository_Name': 'postgraphile',
#   'Star': '11.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphile/postgraphile'},
#  {'Sr No': 116,
#   'User Name': 'withspectrum',
#   'Repository_Name': 'spectrum',
#   'Star': '10.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/withspectrum/spectrum'},
#  {'Sr No': 117,
#   'User Name': 'dotansimha',
#   'Repository_Name': 'graphql-code-generator',
#   'Star': '8.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dotansimha/graphql-code-generator'},
#  {'Sr No': 118,
#   'User Name': 'graphql-go',
#   'Repository_Name': 'graphql',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql-go/graphql'},
#  {'Sr No': 119,
#   'User Name': 'apex',
#   'Repository_Name': 'up',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apex/up'},
#  {'Sr No': 120,
#   'User Name': 'devhubapp',
#   'Repository_Name': 'devhub',
#   'Star': '8.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/devhubapp/devhub'},
#  {'Sr No': 121,
#   'User Name': 'gatsbyjs',
#   'Repository_Name': 'gatsby',
#   'Star': '53.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/gatsbyjs/gatsby'},
#  {'Sr No': 122,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/strapi/strapi'},
#  {'Sr No': 123,
#   'User Name': 'hoppscotch',
#   'Repository_Name': 'hoppscotch',
#   'Star': '44.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hoppscotch/hoppscotch'},
#  {'Sr No': 124,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prettier/prettier'},
#  {'Sr No': 125,
#   'User Name': 'TanStack',
#   'Repository_Name': 'query',
#   'Star': '28.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/TanStack/query'},
#  {'Sr No': 126,
#   'User Name': 'hasura',
#   'Repository_Name': 'graphql-engine',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hasura/graphql-engine'},
#  {'Sr No': 127,
#   'User Name': 'Kong',
#   'Repository_Name': 'insomnia',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/Kong/insomnia'},
#  {'Sr No': 128,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 129,
#   'User Name': 'marmelab',
#   'Repository_Name': 'react-admin',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/marmelab/react-admin'},
#  {'Sr No': 130,
#   'User Name': 'parse-community',
#   'Repository_Name': 'parse-server',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/parse-community/parse-server'},
#  {'Sr No': 131,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphql-js',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphql-js'},
#  {'Sr No': 132,
#   'User Name': 'dgraph-io',
#   'Repository_Name': 'dgraph',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dgraph-io/dgraph'},
#  {'Sr No': 133,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-client',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-client'},
#  {'Sr No': 134,
#   'User Name': 'pubkey',
#   'Repository_Name': 'rxdb',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/pubkey/rxdb'},
#  {'Sr No': 135,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma1',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prisma/prisma1'},
#  {'Sr No': 136,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/directus/directus'},
#  {'Sr No': 137,
#   'User Name': 'saleor',
#   'Repository_Name': 'saleor',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/saleor/saleor'},
#  {'Sr No': 138,
#   'User Name': 'redwoodjs',
#   'Repository_Name': 'redwood',
#   'Star': '14.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/redwoodjs/redwood'},
#  {'Sr No': 139,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphiql',
#   'Star': '13.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphiql'},
#  {'Sr No': 140,
#   'User Name': 'chentsulin',
#   'Repository_Name': 'awesome-graphql',
#   'Star': '13.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/chentsulin/awesome-graphql'},
#  {'Sr No': 141,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-server',
#   'Star': '12.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-server'},
#  {'Sr No': 142,
#   'User Name': 'spree',
#   'Repository_Name': 'spree',
#   'Star': '11.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/spree/spree'},
#  {'Sr No': 143,
#   'User Name': 'reactioncommerce',
#   'Repository_Name': 'reaction',
#   'Star': '11.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/reactioncommerce/reaction'},
#  {'Sr No': 144,
#   'User Name': 'graphql',
#   'Repository_Name': 'dataloader',
#   'Star': '11.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/dataloader'},
#  {'Sr No': 145,
#   'User Name': 'graphile',
#   'Repository_Name': 'postgraphile',
#   'Star': '11.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphile/postgraphile'},
#  {'Sr No': 146,
#   'User Name': 'withspectrum',
#   'Repository_Name': 'spectrum',
#   'Star': '10.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/withspectrum/spectrum'},
#  {'Sr No': 147,
#   'User Name': 'dotansimha',
#   'Repository_Name': 'graphql-code-generator',
#   'Star': '8.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dotansimha/graphql-code-generator'},
#  {'Sr No': 148,
#   'User Name': 'graphql-go',
#   'Repository_Name': 'graphql',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql-go/graphql'},
#  {'Sr No': 149,
#   'User Name': 'apex',
#   'Repository_Name': 'up',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apex/up'},
#  {'Sr No': 150,
#   'User Name': 'devhubapp',
#   'Repository_Name': 'devhub',
#   'Star': '8.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/devhubapp/devhub'},
#  {'Sr No': 151,
#   'User Name': 'gatsbyjs',
#   'Repository_Name': 'gatsby',
#   'Star': '53.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/gatsbyjs/gatsby'},
#  {'Sr No': 152,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/strapi/strapi'},
#  {'Sr No': 153,
#   'User Name': 'hoppscotch',
#   'Repository_Name': 'hoppscotch',
#   'Star': '44.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hoppscotch/hoppscotch'},
#  {'Sr No': 154,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prettier/prettier'},
#  {'Sr No': 155,
#   'User Name': 'TanStack',
#   'Repository_Name': 'query',
#   'Star': '28.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/TanStack/query'},
#  {'Sr No': 156,
#   'User Name': 'hasura',
#   'Repository_Name': 'graphql-engine',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hasura/graphql-engine'},
#  {'Sr No': 157,
#   'User Name': 'Kong',
#   'Repository_Name': 'insomnia',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/Kong/insomnia'},
#  {'Sr No': 158,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 159,
#   'User Name': 'marmelab',
#   'Repository_Name': 'react-admin',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/marmelab/react-admin'},
#  {'Sr No': 160,
#   'User Name': 'parse-community',
#   'Repository_Name': 'parse-server',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/parse-community/parse-server'},
#  {'Sr No': 161,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphql-js',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphql-js'},
#  {'Sr No': 162,
#   'User Name': 'dgraph-io',
#   'Repository_Name': 'dgraph',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dgraph-io/dgraph'},
#  {'Sr No': 163,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-client',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-client'},
#  {'Sr No': 164,
#   'User Name': 'pubkey',
#   'Repository_Name': 'rxdb',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/pubkey/rxdb'},
#  {'Sr No': 165,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma1',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prisma/prisma1'},
#  {'Sr No': 166,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/directus/directus'},
#  {'Sr No': 167,
#   'User Name': 'saleor',
#   'Repository_Name': 'saleor',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/saleor/saleor'},
#  {'Sr No': 168,
#   'User Name': 'redwoodjs',
#   'Repository_Name': 'redwood',
#   'Star': '14.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/redwoodjs/redwood'},
#  {'Sr No': 169,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphiql',
#   'Star': '13.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphiql'},
#  {'Sr No': 170,
#   'User Name': 'chentsulin',
#   'Repository_Name': 'awesome-graphql',
#   'Star': '13.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/chentsulin/awesome-graphql'},
#  {'Sr No': 171,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-server',
#   'Star': '12.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-server'},
#  {'Sr No': 172,
#   'User Name': 'spree',
#   'Repository_Name': 'spree',
#   'Star': '11.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/spree/spree'},
#  {'Sr No': 173,
#   'User Name': 'reactioncommerce',
#   'Repository_Name': 'reaction',
#   'Star': '11.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/reactioncommerce/reaction'},
#  {'Sr No': 174,
#   'User Name': 'graphql',
#   'Repository_Name': 'dataloader',
#   'Star': '11.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/dataloader'},
#  {'Sr No': 175,
#   'User Name': 'graphile',
#   'Repository_Name': 'postgraphile',
#   'Star': '11.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphile/postgraphile'},
#  {'Sr No': 176,
#   'User Name': 'withspectrum',
#   'Repository_Name': 'spectrum',
#   'Star': '10.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/withspectrum/spectrum'},
#  {'Sr No': 177,
#   'User Name': 'dotansimha',
#   'Repository_Name': 'graphql-code-generator',
#   'Star': '8.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dotansimha/graphql-code-generator'},
#  {'Sr No': 178,
#   'User Name': 'graphql-go',
#   'Repository_Name': 'graphql',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql-go/graphql'},
#  {'Sr No': 179,
#   'User Name': 'apex',
#   'Repository_Name': 'up',
#   'Star': '8.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apex/up'},
#  {'Sr No': 180,
#   'User Name': 'devhubapp',
#   'Repository_Name': 'devhub',
#   'Star': '8.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/devhubapp/devhub'},
#  {'Sr No': 181,
#   'User Name': 'gatsbyjs',
#   'Repository_Name': 'gatsby',
#   'Star': '53.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/gatsbyjs/gatsby'},
#  {'Sr No': 182,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/strapi/strapi'},
#  {'Sr No': 183,
#   'User Name': 'hoppscotch',
#   'Repository_Name': 'hoppscotch',
#   'Star': '44.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hoppscotch/hoppscotch'},
#  {'Sr No': 184,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prettier/prettier'},
#  {'Sr No': 185,
#   'User Name': 'TanStack',
#   'Repository_Name': 'query',
#   'Star': '28.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/TanStack/query'},
#  {'Sr No': 186,
#   'User Name': 'hasura',
#   'Repository_Name': 'graphql-engine',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/hasura/graphql-engine'},
#  {'Sr No': 187,
#   'User Name': 'Kong',
#   'Repository_Name': 'insomnia',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/Kong/insomnia'},
#  {'Sr No': 188,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 189,
#   'User Name': 'marmelab',
#   'Repository_Name': 'react-admin',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/marmelab/react-admin'},
#  {'Sr No': 190,
#   'User Name': 'parse-community',
#   'Repository_Name': 'parse-server',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/parse-community/parse-server'},
#  {'Sr No': 191,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphql-js',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphql-js'},
#  {'Sr No': 192,
#   'User Name': 'dgraph-io',
#   'Repository_Name': 'dgraph',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/dgraph-io/dgraph'},
#  {'Sr No': 193,
#   'User Name': 'apollographql',
#   'Repository_Name': 'apollo-client',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/apollographql/apollo-client'},
#  {'Sr No': 194,
#   'User Name': 'pubkey',
#   'Repository_Name': 'rxdb',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/pubkey/rxdb'},
#  {'Sr No': 195,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma1',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/prisma/prisma1'},
#  {'Sr No': 196,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/directus/directus'},
#  {'Sr No': 197,
#   'User Name': 'saleor',
#   'Repository_Name': 'saleor',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/saleor/saleor'},
#  {'Sr No': 198,
#   'User Name': 'redwoodjs',
#   'Repository_Name': 'redwood',
#   'Star': '14.1k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/redwoodjs/redwood'},
#  {'Sr No': 199,
#   'User Name': 'graphql',
#   'Repository_Name': 'graphiql',
#   'Star': '13.8k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/graphql/graphiql'},
#  {'Sr No': 200,
#   'User Name': 'chentsulin',
#   'Repository_Name': 'awesome-graphql',
#   'Star': '13.4k',
#   'Product URL': 'https://github.com/topics/GraphQL?page=/chentsulin/awesome-graphql'}]

# %%
import pandas as pd
final_data= pd.DataFrame(GraphQL_lst)
final_data
# Out:
#      Sr No   User Name  Repository_Name   Star  \
# 0        1    gatsbyjs           gatsby  53.2k
# 1        2      strapi           strapi  46.1k
# 2        3  hoppscotch       hoppscotch  44.7k
# 3        4    prettier         prettier  43.3k
# 4        5    TanStack            query  28.3k
# ..     ...         ...              ...    ...
# 195    196    directus         directus  16.8k
# 196    197      saleor           saleor  16.4k
# 197    198   redwoodjs          redwood  14.1k
# 198    199     graphql         graphiql  13.8k
# 199    200  chentsulin  awesome-graphql  13.4k
#
#                                            Product URL
# 0    https://github.com/topics/GraphQL?page=/gatsby...
# 1    https://github.com/topics/GraphQL?page=/strapi...
# 2    https://github.com/topics/GraphQL?page=/hoppsc...
# 3    https://github.com/topics/GraphQL?page=/pretti...
# 4    https://github.com/topics/GraphQL?page=/TanSta...
# ..                                                 ...
# 195  https://github.com/topics/GraphQL?page=/direct...
# 196  https://github.com/topics/GraphQL?page=/saleor...
# 197  https://github.com/topics/GraphQL?page=/redwoo...
# 198  https://github.com/topics/GraphQL?page=/graphq...
# 199  https://github.com/topics/GraphQL?page=/chents...
#
# [200 rows x 5 columns]

# %%
final_data.to_excel('GraphQL_lst.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\Shraddha'

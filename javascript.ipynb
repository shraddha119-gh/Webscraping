# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/topics/javascript?page='
final_link=[]
for num in range( 1,8):
    final_link.append(base_url+str(num))
    
javascript_dict = {}
javascript_lst = []
SrNo=1
for urls in final_link:
    raw_data = requests.get(urls).text
    soup = BeautifulSoup(raw_data,'lxml')
    all_div=soup.find_all('article', class_="border rounded color-shadow-small color-bg-subtle my-4")
    for item in all_div:
        if(SrNo>200):
            continue
        else:
            repository_name=item.find('a',class_='text-bold wb-break-word').text
            repository_name=repository_name.strip()
            user_name=item.find("h3",class_="f3 color-fg-muted text-normal lh-condensed").text
            user_name=user_name.strip().split("/")[0].strip()
            star=item.find('span',class_='Counter js-social-count').text
            product_link=item.find('a',class_='text-bold wb-break-word')['href']
            product_url = base_url+product_link
            javascript_dict = {
                'Sr No':SrNo,
                'User Name':user_name,
                'Repository_Name':repository_name,
                'Star':star,
                'Product URL':product_url
        
                 }
        javascript_lst.append(javascript_dict)
        SrNo+=1

# %%
javascript_lst
# Out:
# [{'Sr No': 1,
#   'User Name': 'freeCodeCamp',
#   'Repository_Name': 'freeCodeCamp',
#   'Star': '349k',
#   'Product URL': 'https://github.com/topics/javascript?page=/freeCodeCamp/freeCodeCamp'},
#  {'Sr No': 2,
#   'User Name': 'vuejs',
#   'Repository_Name': 'vue',
#   'Star': '197k',
#   'Product URL': 'https://github.com/topics/javascript?page=/vuejs/vue'},
#  {'Sr No': 3,
#   'User Name': 'facebook',
#   'Repository_Name': 'react',
#   'Star': '191k',
#   'Product URL': 'https://github.com/topics/javascript?page=/facebook/react'},
#  {'Sr No': 4,
#   'User Name': 'twbs',
#   'Repository_Name': 'bootstrap',
#   'Star': '158k',
#   'Product URL': 'https://github.com/topics/javascript?page=/twbs/bootstrap'},
#  {'Sr No': 5,
#   'User Name': 'getify',
#   'Repository_Name': 'You-Dont-Know-JS',
#   'Star': '156k',
#   'Product URL': 'https://github.com/topics/javascript?page=/getify/You-Dont-Know-JS'},
#  {'Sr No': 6,
#   'User Name': 'trekhleb',
#   'Repository_Name': 'javascript-algorithms',
#   'Star': '145k',
#   'Product URL': 'https://github.com/topics/javascript?page=/trekhleb/javascript-algorithms'},
#  {'Sr No': 7,
#   'User Name': 'airbnb',
#   'Repository_Name': 'javascript',
#   'Star': '124k',
#   'Product URL': 'https://github.com/topics/javascript?page=/airbnb/javascript'},
#  {'Sr No': 8,
#   'User Name': 'electron',
#   'Repository_Name': 'electron',
#   'Star': '102k',
#   'Product URL': 'https://github.com/topics/javascript?page=/electron/electron'},
#  {'Sr No': 9,
#   'User Name': '30-seconds',
#   'Repository_Name': '30-seconds-of-code',
#   'Star': '98.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/30-seconds/30-seconds-of-code'},
#  {'Sr No': 10,
#   'User Name': 'axios',
#   'Repository_Name': 'axios',
#   'Star': '94.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/axios/axios'},
#  {'Sr No': 11,
#   'User Name': 'justjavac',
#   'Repository_Name': 'free-programming-books-zh_CN',
#   'Star': '94.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/justjavac/free-programming-books-zh_CN'},
#  {'Sr No': 12,
#   'User Name': 'nodejs',
#   'Repository_Name': 'node',
#   'Star': '88.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/nodejs/node'},
#  {'Sr No': 13,
#   'User Name': 'denoland',
#   'Repository_Name': 'deno',
#   'Star': '83.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/denoland/deno'},
#  {'Sr No': 14,
#   'User Name': 'mrdoob',
#   'Repository_Name': 'three.js',
#   'Star': '83.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mrdoob/three.js'},
#  {'Sr No': 15,
#   'User Name': 'angular',
#   'Repository_Name': 'angular',
#   'Star': '82.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/angular/angular'},
#  {'Sr No': 16,
#   'User Name': 'microsoft',
#   'Repository_Name': 'TypeScript',
#   'Star': '82k',
#   'Product URL': 'https://github.com/topics/javascript?page=/microsoft/TypeScript'},
#  {'Sr No': 17,
#   'User Name': 'mui',
#   'Repository_Name': 'material-ui',
#   'Star': '79.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mui/material-ui'},
#  {'Sr No': 18,
#   'User Name': 'goldbergyoni',
#   'Repository_Name': 'nodebestpractices',
#   'Star': '79k',
#   'Product URL': 'https://github.com/topics/javascript?page=/goldbergyoni/nodebestpractices'},
#  {'Sr No': 19,
#   'User Name': 'storybookjs',
#   'Repository_Name': 'storybook',
#   'Star': '72.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/storybookjs/storybook'},
#  {'Sr No': 20,
#   'User Name': 'practical-tutorials',
#   'Repository_Name': 'project-based-learning',
#   'Star': '71.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/practical-tutorials/project-based-learning'},
#  {'Sr No': 21,
#   'User Name': 'ryanmcdermott',
#   'Repository_Name': 'clean-code-javascript',
#   'Star': '69.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ryanmcdermott/clean-code-javascript'},
#  {'Sr No': 22,
#   'User Name': 'webpack',
#   'Repository_Name': 'webpack',
#   'Star': '61.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/webpack/webpack'},
#  {'Sr No': 23,
#   'User Name': 'thedaviddias',
#   'Repository_Name': 'Front-End-Checklist',
#   'Star': '60.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/thedaviddias/Front-End-Checklist'},
#  {'Sr No': 24,
#   'User Name': 'atom',
#   'Repository_Name': 'atom',
#   'Star': '58.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/atom/atom'},
#  {'Sr No': 25,
#   'User Name': 'expressjs',
#   'Repository_Name': 'express',
#   'Star': '57.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/expressjs/express'},
#  {'Sr No': 26,
#   'User Name': 'chartjs',
#   'Repository_Name': 'Chart.js',
#   'Star': '57.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/chartjs/Chart.js'},
#  {'Sr No': 27,
#   'User Name': 'microsoft',
#   'Repository_Name': 'Web-Dev-For-Beginners',
#   'Star': '53.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/microsoft/Web-Dev-For-Beginners'},
#  {'Sr No': 28,
#   'User Name': 'lodash',
#   'Repository_Name': 'lodash',
#   'Star': '53.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/lodash/lodash'},
#  {'Sr No': 29,
#   'User Name': 'h5bp',
#   'Repository_Name': 'html5-boilerplate',
#   'Star': '53.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/h5bp/html5-boilerplate'},
#  {'Sr No': 30,
#   'User Name': 'ElemeFE',
#   'Repository_Name': 'element',
#   'Star': '52.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ElemeFE/element'},
#  {'Sr No': 31,
#   'User Name': 'leonardomso',
#   'Repository_Name': '33-js-concepts',
#   'Star': '49.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/leonardomso/33-js-concepts'},
#  {'Sr No': 32,
#   'User Name': 'azl397985856',
#   'Repository_Name': 'leetcode',
#   'Star': '48.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/azl397985856/leetcode'},
#  {'Sr No': 33,
#   'User Name': 'nestjs',
#   'Repository_Name': 'nest',
#   'Star': '48.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/nestjs/nest'},
#  {'Sr No': 34,
#   'User Name': 'ionic-team',
#   'Repository_Name': 'ionic-framework',
#   'Star': '47.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ionic-team/ionic-framework'},
#  {'Sr No': 35,
#   'User Name': 'DopplerHQ',
#   'Repository_Name': 'awesome-interview-questions',
#   'Star': '47.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/DopplerHQ/awesome-interview-questions'},
#  {'Sr No': 36,
#   'User Name': 'strapi',
#   'Repository_Name': 'strapi',
#   'Star': '46.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/strapi/strapi'},
#  {'Sr No': 37,
#   'User Name': 'sindresorhus',
#   'Repository_Name': 'awesome-nodejs',
#   'Star': '45.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/sindresorhus/awesome-nodejs'},
#  {'Sr No': 38,
#   'User Name': 'prettier',
#   'Repository_Name': 'prettier',
#   'Star': '43.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/prettier/prettier'},
#  {'Sr No': 39,
#   'User Name': 'meteor',
#   'Repository_Name': 'meteor',
#   'Star': '42.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/meteor/meteor'},
#  {'Sr No': 40,
#   'User Name': 'juliangarnier',
#   'Repository_Name': 'anime',
#   'Star': '42.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/juliangarnier/anime'},
#  {'Sr No': 41,
#   'User Name': 'babel',
#   'Repository_Name': 'babel',
#   'Star': '41.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/babel/babel'},
#  {'Sr No': 42,
#   'User Name': 'parcel-bundler',
#   'Repository_Name': 'parcel',
#   'Star': '41k',
#   'Product URL': 'https://github.com/topics/javascript?page=/parcel-bundler/parcel'},
#  {'Sr No': 43,
#   'User Name': 'yarnpkg',
#   'Repository_Name': 'yarn',
#   'Star': '40.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/yarnpkg/yarn'},
#  {'Sr No': 44,
#   'User Name': 'TryGhost',
#   'Repository_Name': 'Ghost',
#   'Star': '40.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/TryGhost/Ghost'},
#  {'Sr No': 45,
#   'User Name': 'microsoft',
#   'Repository_Name': 'playwright',
#   'Star': '39.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/microsoft/playwright'},
#  {'Sr No': 46,
#   'User Name': 'facebook',
#   'Repository_Name': 'jest',
#   'Star': '39.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/facebook/jest'},
#  {'Sr No': 47,
#   'User Name': 'nwjs',
#   'Repository_Name': 'nw.js',
#   'Star': '39k',
#   'Product URL': 'https://github.com/topics/javascript?page=/nwjs/nw.js'},
#  {'Sr No': 48,
#   'User Name': 'vercel',
#   'Repository_Name': 'hyper',
#   'Star': '38.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/vercel/hyper'},
#  {'Sr No': 49,
#   'User Name': 'Dogfalo',
#   'Repository_Name': 'materialize',
#   'Star': '38.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/Dogfalo/materialize'},
#  {'Sr No': 50,
#   'User Name': 'pixijs',
#   'Repository_Name': 'pixijs',
#   'Star': '36.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/pixijs/pixijs'},
#  {'Sr No': 51,
#   'User Name': 'dcloudio',
#   'Repository_Name': 'uni-app',
#   'Star': '36.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/dcloudio/uni-app'},
#  {'Sr No': 52,
#   'User Name': 'FreeCodeCampChina',
#   'Repository_Name': 'freecodecamp.cn',
#   'Star': '36.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/FreeCodeCampChina/freecodecamp.cn'},
#  {'Sr No': 53,
#   'User Name': 'discourse',
#   'Repository_Name': 'discourse',
#   'Star': '36k',
#   'Product URL': 'https://github.com/topics/javascript?page=/discourse/discourse'},
#  {'Sr No': 54,
#   'User Name': 'hexojs',
#   'Repository_Name': 'hexo',
#   'Star': '35k',
#   'Product URL': 'https://github.com/topics/javascript?page=/hexojs/hexo'},
#  {'Sr No': 55,
#   'User Name': 'Leaflet',
#   'Repository_Name': 'Leaflet',
#   'Star': '34.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/Leaflet/Leaflet'},
#  {'Sr No': 56,
#   'User Name': 'vuetifyjs',
#   'Repository_Name': 'vuetify',
#   'Star': '34.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/vuetifyjs/vuetify'},
#  {'Sr No': 57,
#   'User Name': 'facebook',
#   'Repository_Name': 'docusaurus',
#   'Star': '34.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/facebook/docusaurus'},
#  {'Sr No': 58,
#   'User Name': 'yangshun',
#   'Repository_Name': 'front-end-interview-handbook',
#   'Star': '34.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/yangshun/front-end-interview-handbook'},
#  {'Sr No': 59,
#   'User Name': 'alvarotrigo',
#   'Repository_Name': 'fullPage.js',
#   'Star': '33.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/alvarotrigo/fullPage.js'},
#  {'Sr No': 60,
#   'User Name': 'videojs',
#   'Repository_Name': 'video.js',
#   'Star': '33.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/videojs/video.js'},
#  {'Sr No': 61,
#   'User Name': 'google',
#   'Repository_Name': 'zx',
#   'Star': '32.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/google/zx'},
#  {'Sr No': 62,
#   'User Name': 'RocketChat',
#   'Repository_Name': 'Rocket.Chat',
#   'Star': '32.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/RocketChat/Rocket.Chat'},
#  {'Sr No': 63,
#   'User Name': 'evanw',
#   'Repository_Name': 'esbuild',
#   'Star': '32.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/evanw/esbuild'},
#  {'Sr No': 64,
#   'User Name': 'zenorocha',
#   'Repository_Name': 'clipboard.js',
#   'Star': '32.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/zenorocha/clipboard.js'},
#  {'Sr No': 65,
#   'User Name': 'photonstorm',
#   'Repository_Name': 'phaser',
#   'Star': '32k',
#   'Product URL': 'https://github.com/topics/javascript?page=/photonstorm/phaser'},
#  {'Sr No': 66,
#   'User Name': 'NervJS',
#   'Repository_Name': 'taro',
#   'Star': '31.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/NervJS/taro'},
#  {'Sr No': 67,
#   'User Name': 'gorhill',
#   'Repository_Name': 'uBlock',
#   'Star': '31k',
#   'Product URL': 'https://github.com/topics/javascript?page=/gorhill/uBlock'},
#  {'Sr No': 68,
#   'User Name': 'serhii-londar',
#   'Repository_Name': 'open-source-mac-os-apps',
#   'Star': '31k',
#   'Product URL': 'https://github.com/topics/javascript?page=/serhii-londar/open-source-mac-os-apps'},
#  {'Sr No': 69,
#   'User Name': 'xitu',
#   'Repository_Name': 'gold-miner',
#   'Star': '30.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/xitu/gold-miner'},
#  {'Sr No': 70,
#   'User Name': 'SheetJS',
#   'Repository_Name': 'sheetjs',
#   'Star': '30.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/SheetJS/sheetjs'},
#  {'Sr No': 71,
#   'User Name': 'carbon-app',
#   'Repository_Name': 'carbon',
#   'Star': '30.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/carbon-app/carbon'},
#  {'Sr No': 72,
#   'User Name': 'laurent22',
#   'Repository_Name': 'joplin',
#   'Star': '30.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/laurent22/joplin'},
#  {'Sr No': 73,
#   'User Name': 'LeCoupa',
#   'Repository_Name': 'awesome-cheatsheets',
#   'Star': '29.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/LeCoupa/awesome-cheatsheets'},
#  {'Sr No': 74,
#   'User Name': 'date-fns',
#   'Repository_Name': 'date-fns',
#   'Star': '29.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/date-fns/date-fns'},
#  {'Sr No': 75,
#   'User Name': 'youngyangyang04',
#   'Repository_Name': 'leetcode-master',
#   'Star': '29.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/youngyangyang04/leetcode-master'},
#  {'Sr No': 76,
#   'User Name': 'typeorm',
#   'Repository_Name': 'typeorm',
#   'Star': '28.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/typeorm/typeorm'},
#  {'Sr No': 77,
#   'User Name': 'vuejs',
#   'Repository_Name': 'vuex',
#   'Star': '27.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/vuejs/vuex'},
#  {'Sr No': 78,
#   'User Name': 'caolan',
#   'Repository_Name': 'async',
#   'Star': '27.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/caolan/async'},
#  {'Sr No': 79,
#   'User Name': 'mqyqingfeng',
#   'Repository_Name': 'Blog',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mqyqingfeng/Blog'},
#  {'Sr No': 80,
#   'User Name': 'ReactiveX',
#   'Repository_Name': 'rxjs',
#   'Star': '27.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ReactiveX/rxjs'},
#  {'Sr No': 81,
#   'User Name': 'standard',
#   'Repository_Name': 'standard',
#   'Star': '27.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/standard/standard'},
#  {'Sr No': 82,
#   'User Name': 'naptha',
#   'Repository_Name': 'tesseract.js',
#   'Star': '27.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/naptha/tesseract.js'},
#  {'Sr No': 83,
#   'User Name': 'elsewhencode',
#   'Repository_Name': 'project-guidelines',
#   'Star': '27k',
#   'Product URL': 'https://github.com/topics/javascript?page=/elsewhencode/project-guidelines'},
#  {'Sr No': 84,
#   'User Name': 'denysdovhan',
#   'Repository_Name': 'wtfjs',
#   'Star': '27k',
#   'Product URL': 'https://github.com/topics/javascript?page=/denysdovhan/wtfjs'},
#  {'Sr No': 85,
#   'User Name': 'webtorrent',
#   'Repository_Name': 'webtorrent',
#   'Star': '26.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/webtorrent/webtorrent'},
#  {'Sr No': 86,
#   'User Name': 'sequelize',
#   'Repository_Name': 'sequelize',
#   'Star': '26.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/sequelize/sequelize'},
#  {'Sr No': 87,
#   'User Name': 'layui',
#   'Repository_Name': 'layui',
#   'Star': '26.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/layui/layui'},
#  {'Sr No': 88,
#   'User Name': 'niklasvh',
#   'Repository_Name': 'html2canvas',
#   'Star': '26.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/niklasvh/html2canvas'},
#  {'Sr No': 89,
#   'User Name': 'Advanced-Frontend',
#   'Repository_Name': 'Daily-Interview-Question',
#   'Star': '25.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/Advanced-Frontend/Daily-Interview-Question'},
#  {'Sr No': 90,
#   'User Name': 'transloadit',
#   'Repository_Name': 'uppy',
#   'Star': '25.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/transloadit/uppy'},
#  {'Sr No': 91,
#   'User Name': 'mobxjs',
#   'Repository_Name': 'mobx',
#   'Star': '25.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mobxjs/mobx'},
#  {'Sr No': 92,
#   'User Name': 'select2',
#   'Repository_Name': 'select2',
#   'Star': '25.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/select2/select2'},
#  {'Sr No': 93,
#   'User Name': 'github',
#   'Repository_Name': 'fetch',
#   'Star': '25.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/github/fetch'},
#  {'Sr No': 94,
#   'User Name': 'Modernizr',
#   'Repository_Name': 'Modernizr',
#   'Star': '25.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/Modernizr/Modernizr'},
#  {'Sr No': 95,
#   'User Name': 'ianstormtaylor',
#   'Repository_Name': 'slate',
#   'Star': '24.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ianstormtaylor/slate'},
#  {'Sr No': 96,
#   'User Name': 'Binaryify',
#   'Repository_Name': 'NeteaseCloudMusicApi',
#   'Star': '24.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/Binaryify/NeteaseCloudMusicApi'},
#  {'Sr No': 97,
#   'User Name': 'nylas',
#   'Repository_Name': 'nylas-mail',
#   'Star': '24.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/nylas/nylas-mail'},
#  {'Sr No': 98,
#   'User Name': 'SeleniumHQ',
#   'Repository_Name': 'selenium',
#   'Star': '24k',
#   'Product URL': 'https://github.com/topics/javascript?page=/SeleniumHQ/selenium'},
#  {'Sr No': 99,
#   'User Name': 'prisma',
#   'Repository_Name': 'prisma',
#   'Star': '24k',
#   'Product URL': 'https://github.com/topics/javascript?page=/prisma/prisma'},
#  {'Sr No': 100,
#   'User Name': 'iview',
#   'Repository_Name': 'iview',
#   'Star': '24k',
#   'Product URL': 'https://github.com/topics/javascript?page=/iview/iview'},
#  {'Sr No': 101,
#   'User Name': 'appwrite',
#   'Repository_Name': 'appwrite',
#   'Star': '23.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/appwrite/appwrite'},
#  {'Sr No': 102,
#   'User Name': 'mbeaudru',
#   'Repository_Name': 'modern-js-cheatsheet',
#   'Star': '23k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mbeaudru/modern-js-cheatsheet'},
#  {'Sr No': 103,
#   'User Name': 'swc-project',
#   'Repository_Name': 'swc',
#   'Star': '22.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/swc-project/swc'},
#  {'Sr No': 104,
#   'User Name': 'lovell',
#   'Repository_Name': 'sharp',
#   'Star': '22.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/lovell/sharp'},
#  {'Sr No': 105,
#   'User Name': 'mdbootstrap',
#   'Repository_Name': 'mdb-ui-kit',
#   'Star': '22.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mdbootstrap/mdb-ui-kit'},
#  {'Sr No': 106,
#   'User Name': 'sampotts',
#   'Repository_Name': 'plyr',
#   'Star': '22.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/sampotts/plyr'},
#  {'Sr No': 107,
#   'User Name': 'emberjs',
#   'Repository_Name': 'ember.js',
#   'Star': '22.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/emberjs/ember.js'},
#  {'Sr No': 108,
#   'User Name': 'ramda',
#   'Repository_Name': 'ramda',
#   'Star': '22.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ramda/ramda'},
#  {'Sr No': 109,
#   'User Name': 't4t5',
#   'Repository_Name': 'sweetalert',
#   'Star': '22k',
#   'Product URL': 'https://github.com/topics/javascript?page=/t4t5/sweetalert'},
#  {'Sr No': 110,
#   'User Name': 'sudheerj',
#   'Repository_Name': 'reactjs-interview-questions',
#   'Star': '22.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/sudheerj/reactjs-interview-questions'},
#  {'Sr No': 111,
#   'User Name': 'dimsemenov',
#   'Repository_Name': 'PhotoSwipe',
#   'Star': '22k',
#   'Product URL': 'https://github.com/topics/javascript?page=/dimsemenov/PhotoSwipe'},
#  {'Sr No': 112,
#   'User Name': 'feathericons',
#   'Repository_Name': 'feather',
#   'Star': '21.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/feathericons/feather'},
#  {'Sr No': 113,
#   'User Name': 'MostlyAdequate',
#   'Repository_Name': 'mostly-adequate-guide',
#   'Star': '21.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/MostlyAdequate/mostly-adequate-guide'},
#  {'Sr No': 114,
#   'User Name': 'markerikson',
#   'Repository_Name': 'react-redux-links',
#   'Star': '21.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/markerikson/react-redux-links'},
#  {'Sr No': 115,
#   'User Name': 'quasarframework',
#   'Repository_Name': 'quasar',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/quasarframework/quasar'},
#  {'Sr No': 116,
#   'User Name': 'mochajs',
#   'Repository_Name': 'mocha',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mochajs/mocha'},
#  {'Sr No': 117,
#   'User Name': 'haizlin',
#   'Repository_Name': 'fe-interview',
#   'Star': '21.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/haizlin/fe-interview'},
#  {'Sr No': 118,
#   'User Name': 'NativeScript',
#   'Repository_Name': 'NativeScript',
#   'Star': '21.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/NativeScript/NativeScript'},
#  {'Sr No': 119,
#   'User Name': 'usablica',
#   'Repository_Name': 'intro.js',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/usablica/intro.js'},
#  {'Sr No': 120,
#   'User Name': 'getredash',
#   'Repository_Name': 'redash',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/getredash/redash'},
#  {'Sr No': 121,
#   'User Name': 'kriasoft',
#   'Repository_Name': 'react-starter-kit',
#   'Star': '21.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/kriasoft/react-starter-kit'},
#  {'Sr No': 122,
#   'User Name': 'bevacqua',
#   'Repository_Name': 'dragula',
#   'Star': '21.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/bevacqua/dragula'},
#  {'Sr No': 123,
#   'User Name': 'paularmstrong',
#   'Repository_Name': 'normalizr',
#   'Star': '20.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/paularmstrong/normalizr'},
#  {'Sr No': 124,
#   'User Name': 'react-bootstrap',
#   'Repository_Name': 'react-bootstrap',
#   'Star': '20.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/react-bootstrap/react-bootstrap'},
#  {'Sr No': 125,
#   'User Name': 'eslint',
#   'Repository_Name': 'eslint',
#   'Star': '20.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/eslint/eslint'},
#  {'Sr No': 126,
#   'User Name': 'jlmakes',
#   'Repository_Name': 'scrollreveal',
#   'Star': '20.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/jlmakes/scrollreveal'},
#  {'Sr No': 127,
#   'User Name': 'localForage',
#   'Repository_Name': 'localForage',
#   'Star': '20.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/localForage/localForage'},
#  {'Sr No': 128,
#   'User Name': 'statelyai',
#   'Repository_Name': 'xstate',
#   'Star': '20.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/statelyai/xstate'},
#  {'Sr No': 129,
#   'User Name': 'qianguyihao',
#   'Repository_Name': 'Web',
#   'Star': '20.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/qianguyihao/Web'},
#  {'Sr No': 130,
#   'User Name': 'TheAlgorithms',
#   'Repository_Name': 'JavaScript',
#   'Star': '20.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/TheAlgorithms/JavaScript'},
#  {'Sr No': 131,
#   'User Name': 'goldfire',
#   'Repository_Name': 'howler.js',
#   'Star': '20.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/goldfire/howler.js'},
#  {'Sr No': 132,
#   'User Name': 'highlightjs',
#   'Repository_Name': 'highlight.js',
#   'Star': '20.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/highlightjs/highlight.js'},
#  {'Sr No': 133,
#   'User Name': 'avajs',
#   'Repository_Name': 'ava',
#   'Star': '19.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/avajs/ava'},
#  {'Sr No': 134,
#   'User Name': 'electron-react-boilerplate',
#   'Repository_Name': 'electron-react-boilerplate',
#   'Star': '19.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/electron-react-boilerplate/electron-react-boilerplate'},
#  {'Sr No': 135,
#   'User Name': 'solidjs',
#   'Repository_Name': 'solid',
#   'Star': '20k',
#   'Product URL': 'https://github.com/topics/javascript?page=/solidjs/solid'},
#  {'Sr No': 136,
#   'User Name': 'validatorjs',
#   'Repository_Name': 'validator.js',
#   'Star': '19.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/validatorjs/validator.js'},
#  {'Sr No': 137,
#   'User Name': 'v8',
#   'Repository_Name': 'v8',
#   'Star': '19.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/v8/v8'},
#  {'Sr No': 138,
#   'User Name': 'js-cookie',
#   'Repository_Name': 'js-cookie',
#   'Star': '19.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/js-cookie/js-cookie'},
#  {'Sr No': 139,
#   'User Name': 'nextcloud',
#   'Repository_Name': 'server',
#   'Star': '19.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/nextcloud/server'},
#  {'Sr No': 140,
#   'User Name': 'appsmithorg',
#   'Repository_Name': 'appsmith',
#   'Star': '19.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/appsmithorg/appsmith'},
#  {'Sr No': 141,
#   'User Name': 'codex-team',
#   'Repository_Name': 'editor.js',
#   'Star': '19.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/codex-team/editor.js'},
#  {'Sr No': 142,
#   'User Name': 'benweet',
#   'Repository_Name': 'stackedit',
#   'Star': '19.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/benweet/stackedit'},
#  {'Sr No': 143,
#   'User Name': 'verekia',
#   'Repository_Name': 'js-stack-from-scratch',
#   'Star': '19.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/verekia/js-stack-from-scratch'},
#  {'Sr No': 144,
#   'User Name': 'lyswhut',
#   'Repository_Name': 'lx-music-desktop',
#   'Star': '19k',
#   'Product URL': 'https://github.com/topics/javascript?page=/lyswhut/lx-music-desktop'},
#  {'Sr No': 145,
#   'User Name': 'sideway',
#   'Repository_Name': 'joi',
#   'Star': '18.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/sideway/joi'},
#  {'Sr No': 146,
#   'User Name': 'vuejs',
#   'Repository_Name': 'vue-router',
#   'Star': '18.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/vuejs/vue-router'},
#  {'Sr No': 147,
#   'User Name': 'jorgebucaran',
#   'Repository_Name': 'hyperapp',
#   'Star': '18.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/jorgebucaran/hyperapp'},
#  {'Sr No': 148,
#   'User Name': 'chalk',
#   'Repository_Name': 'chalk',
#   'Star': '18.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/chalk/chalk'},
#  {'Sr No': 149,
#   'User Name': 'vadimdemedes',
#   'Repository_Name': 'ink',
#   'Star': '18.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/vadimdemedes/ink'},
#  {'Sr No': 150,
#   'User Name': 'websockets',
#   'Repository_Name': 'ws',
#   'Star': '18.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/websockets/ws'},
#  {'Sr No': 151,
#   'User Name': 'qier222',
#   'Repository_Name': 'YesPlayMusic',
#   'Star': '18.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/qier222/YesPlayMusic'},
#  {'Sr No': 152,
#   'User Name': 'google',
#   'Repository_Name': 'flatbuffers',
#   'Star': '18.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/google/flatbuffers'},
#  {'Sr No': 153,
#   'User Name': 'pnpm',
#   'Repository_Name': 'pnpm',
#   'Star': '18.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/pnpm/pnpm'},
#  {'Sr No': 154,
#   'User Name': 'wekan',
#   'Repository_Name': 'wekan',
#   'Star': '18.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/wekan/wekan'},
#  {'Sr No': 155,
#   'User Name': 'TanStack',
#   'Repository_Name': 'table',
#   'Star': '18.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/TanStack/table'},
#  {'Sr No': 156,
#   'User Name': 'goldbergyoni',
#   'Repository_Name': 'javascript-testing-best-practices',
#   'Star': '18.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/goldbergyoni/javascript-testing-best-practices'},
#  {'Sr No': 157,
#   'User Name': 'svg',
#   'Repository_Name': 'svgo',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/svg/svgo'},
#  {'Sr No': 158,
#   'User Name': 'InterviewMap',
#   'Repository_Name': 'CS-Interview-Knowledge-Map',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/InterviewMap/CS-Interview-Knowledge-Map'},
#  {'Sr No': 159,
#   'User Name': 'typicode',
#   'Repository_Name': 'lowdb',
#   'Star': '17.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/typicode/lowdb'},
#  {'Sr No': 160,
#   'User Name': 'processing',
#   'Repository_Name': 'p5.js',
#   'Star': '17.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/processing/p5.js'},
#  {'Sr No': 161,
#   'User Name': 'airyland',
#   'Repository_Name': 'vux',
#   'Star': '17.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/airyland/vux'},
#  {'Sr No': 162,
#   'User Name': 'mojs',
#   'Repository_Name': 'mojs',
#   'Star': '17.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mojs/mojs'},
#  {'Sr No': 163,
#   'User Name': 'jsdom',
#   'Repository_Name': 'jsdom',
#   'Star': '17.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/jsdom/jsdom'},
#  {'Sr No': 164,
#   'User Name': 'mysqljs',
#   'Repository_Name': 'mysql',
#   'Star': '17.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/mysqljs/mysql'},
#  {'Sr No': 165,
#   'User Name': 'you-dont-need',
#   'Repository_Name': 'You-Dont-Need-JavaScript',
#   'Star': '17.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/you-dont-need/You-Dont-Need-JavaScript'},
#  {'Sr No': 166,
#   'User Name': 'oracle',
#   'Repository_Name': 'graal',
#   'Star': '17.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/oracle/graal'},
#  {'Sr No': 167,
#   'User Name': 'grafana',
#   'Repository_Name': 'k6',
#   'Star': '17k',
#   'Product URL': 'https://github.com/topics/javascript?page=/grafana/k6'},
#  {'Sr No': 168,
#   'User Name': 'zloirock',
#   'Repository_Name': 'core-js',
#   'Star': '17k',
#   'Product URL': 'https://github.com/topics/javascript?page=/zloirock/core-js'},
#  {'Sr No': 169,
#   'User Name': 'fingerprintjs',
#   'Repository_Name': 'fingerprintjs',
#   'Star': '17k',
#   'Product URL': 'https://github.com/topics/javascript?page=/fingerprintjs/fingerprintjs'},
#  {'Sr No': 170,
#   'User Name': 'basecamp',
#   'Repository_Name': 'trix',
#   'Star': '16.9k',
#   'Product URL': 'https://github.com/topics/javascript?page=/basecamp/trix'},
#  {'Sr No': 171,
#   'User Name': 'yudai',
#   'Repository_Name': 'gotty',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/yudai/gotty'},
#  {'Sr No': 172,
#   'User Name': 'responsively-org',
#   'Repository_Name': 'responsively-app',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/responsively-org/responsively-app'},
#  {'Sr No': 173,
#   'User Name': 'directus',
#   'Repository_Name': 'directus',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/directus/directus'},
#  {'Sr No': 174,
#   'User Name': 'angular',
#   'Repository_Name': 'material',
#   'Star': '16.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/angular/material'},
#  {'Sr No': 175,
#   'User Name': 'MichMich',
#   'Repository_Name': 'MagicMirror',
#   'Star': '16.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/MichMich/MagicMirror'},
#  {'Sr No': 176,
#   'User Name': 'dropzone',
#   'Repository_Name': 'dropzone',
#   'Star': '16.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/dropzone/dropzone'},
#  {'Sr No': 177,
#   'User Name': 'PanJiaChen',
#   'Repository_Name': 'vue-admin-template',
#   'Star': '16.7k',
#   'Product URL': 'https://github.com/topics/javascript?page=/PanJiaChen/vue-admin-template'},
#  {'Sr No': 178,
#   'User Name': 'testing-library',
#   'Repository_Name': 'react-testing-library',
#   'Star': '16.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/testing-library/react-testing-library'},
#  {'Sr No': 179,
#   'User Name': 'statsd',
#   'Repository_Name': 'statsd',
#   'Star': '16.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/statsd/statsd'},
#  {'Sr No': 180,
#   'User Name': 'bokeh',
#   'Repository_Name': 'bokeh',
#   'Star': '16.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/bokeh/bokeh'},
#  {'Sr No': 181,
#   'User Name': 'alsotang',
#   'Repository_Name': 'node-lessons',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/alsotang/node-lessons'},
#  {'Sr No': 182,
#   'User Name': 'tensorflow',
#   'Repository_Name': 'tfjs',
#   'Star': '16.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/tensorflow/tfjs'},
#  {'Sr No': 183,
#   'User Name': 'material-components',
#   'Repository_Name': 'material-components-web',
#   'Star': '16.3k',
#   'Product URL': 'https://github.com/topics/javascript?page=/material-components/material-components-web'},
#  {'Sr No': 184,
#   'User Name': 'aFarkas',
#   'Repository_Name': 'lazysizes',
#   'Star': '16.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/aFarkas/lazysizes'},
#  {'Sr No': 185,
#   'User Name': 'Shopify',
#   'Repository_Name': 'draggable',
#   'Star': '16.2k',
#   'Product URL': 'https://github.com/topics/javascript?page=/Shopify/draggable'},
#  {'Sr No': 186,
#   'User Name': 'reddit-archive',
#   'Repository_Name': 'reddit',
#   'Star': '16.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/reddit-archive/reddit'},
#  {'Sr No': 187,
#   'User Name': 'zulip',
#   'Repository_Name': 'zulip',
#   'Star': '16.1k',
#   'Product URL': 'https://github.com/topics/javascript?page=/zulip/zulip'},
#  {'Sr No': 188,
#   'User Name': 'knex',
#   'Repository_Name': 'knex',
#   'Star': '16k',
#   'Product URL': 'https://github.com/topics/javascript?page=/knex/knex'},
#  {'Sr No': 189,
#   'User Name': 'react-grid-layout',
#   'Repository_Name': 'react-grid-layout',
#   'Star': '16k',
#   'Product URL': 'https://github.com/topics/javascript?page=/react-grid-layout/react-grid-layout'},
#  {'Sr No': 190,
#   'User Name': 'outline',
#   'Repository_Name': 'outline',
#   'Star': '15.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/outline/outline'},
#  {'Sr No': 191,
#   'User Name': 'GitHubDaily',
#   'Repository_Name': 'GitHubDaily',
#   'Star': '15.8k',
#   'Product URL': 'https://github.com/topics/javascript?page=/GitHubDaily/GitHubDaily'},
#  {'Sr No': 192,
#   'User Name': 'tc39',
#   'Repository_Name': 'proposals',
#   'Star': '15.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/tc39/proposals'},
#  {'Sr No': 193,
#   'User Name': 'yabwe',
#   'Repository_Name': 'medium-editor',
#   'Star': '15.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/yabwe/medium-editor'},
#  {'Sr No': 194,
#   'User Name': 'KaTeX',
#   'Repository_Name': 'KaTeX',
#   'Star': '15.6k',
#   'Product URL': 'https://github.com/topics/javascript?page=/KaTeX/KaTeX'},
#  {'Sr No': 195,
#   'User Name': 'ChainSafe',
#   'Repository_Name': 'web3.js',
#   'Star': '15.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ChainSafe/web3.js'},
#  {'Sr No': 196,
#   'User Name': 'salomonelli',
#   'Repository_Name': 'best-resume-ever',
#   'Star': '15.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/salomonelli/best-resume-ever'},
#  {'Sr No': 197,
#   'User Name': 'ueberdosis',
#   'Repository_Name': 'tiptap',
#   'Star': '15.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/ueberdosis/tiptap'},
#  {'Sr No': 198,
#   'User Name': 'netlify',
#   'Repository_Name': 'netlify-cms',
#   'Star': '15.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/netlify/netlify-cms'},
#  {'Sr No': 199,
#   'User Name': 'getify',
#   'Repository_Name': 'Functional-Light-JS',
#   'Star': '15.5k',
#   'Product URL': 'https://github.com/topics/javascript?page=/getify/Functional-Light-JS'},
#  {'Sr No': 200,
#   'User Name': 'teambit',
#   'Repository_Name': 'bit',
#   'Star': '15.4k',
#   'Product URL': 'https://github.com/topics/javascript?page=/teambit/bit'}]

# %%
import pandas as pd
final_data= pd.DataFrame(javascript_lst)
final_data
# Out:
#      Sr No     User Name      Repository_Name   Star  \
# 0        1  freeCodeCamp         freeCodeCamp   349k
# 1        2         vuejs                  vue   197k
# 2        3      facebook                react   191k
# 3        4          twbs            bootstrap   158k
# 4        5        getify     You-Dont-Know-JS   156k
# ..     ...           ...                  ...    ...
# 195    196   salomonelli     best-resume-ever  15.5k
# 196    197    ueberdosis               tiptap  15.5k
# 197    198       netlify          netlify-cms  15.5k
# 198    199        getify  Functional-Light-JS  15.5k
# 199    200       teambit                  bit  15.4k
#
#                                            Product URL
# 0    https://github.com/topics/javascript?page=/fre...
# 1    https://github.com/topics/javascript?page=/vue...
# 2    https://github.com/topics/javascript?page=/fac...
# 3    https://github.com/topics/javascript?page=/twb...
# 4    https://github.com/topics/javascript?page=/get...
# ..                                                 ...
# 195  https://github.com/topics/javascript?page=/sal...
# 196  https://github.com/topics/javascript?page=/ueb...
# 197  https://github.com/topics/javascript?page=/net...
# 198  https://github.com/topics/javascript?page=/get...
# 199  https://github.com/topics/javascript?page=/tea...
#
# [200 rows x 5 columns]

# %%
final_data.to_excel('javascript_lst.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\Shraddha'

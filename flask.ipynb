# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/topics/flask?page='
final_link=[]
for num in range( 1,8):
    final_link.append(base_url+str(num))
flask_dict = {}
flask_lst = []
SrNo=1
for urls in final_link:
    raw_data = requests.get(urls).text
    soup = BeautifulSoup(raw_data,'lxml')
    all_div=soup.find_all('article', class_="border rounded color-shadow-small color-bg-subtle my-4")
    for item in all_div:
        if(SrNo>200):
            continue
        else:
            repository_name=item.find('a',class_='text-bold wb-break-word').text
            repository_name=repository_name.strip()
            user_name=item.find("h3",class_="f3 color-fg-muted text-normal lh-condensed").text
            user_name=user_name.strip().split("/")[0].strip()
            star=item.find('span',class_='Counter js-social-count').text
            product_link=item.find('a',class_='text-bold wb-break-word')['href']
            product_url = base_url+product_link
            flask_dict = {
                'Sr No':SrNo,
                'User Name':user_name,
                'Repository_Name':repository_name,
                'Star':star,
                'Product URL':product_url
        
                 }
        flask_lst.append(flask_dict)
        SrNo+=1

# %%
flask_lst
# Out:
# [{'Sr No': 1,
#   'User Name': 'pallets',
#   'Repository_Name': 'flask',
#   'Star': '59.7k',
#   'Product URL': 'https://github.com/topics/flask?page=/pallets/flask'},
#  {'Sr No': 2,
#   'User Name': 'apache',
#   'Repository_Name': 'superset',
#   'Star': '46.9k',
#   'Product URL': 'https://github.com/topics/flask?page=/apache/superset'},
#  {'Sr No': 3,
#   'User Name': 'plotly',
#   'Repository_Name': 'dash',
#   'Star': '16.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/plotly/dash'},
#  {'Sr No': 4,
#   'User Name': 'jhao104',
#   'Repository_Name': 'proxy_pool',
#   'Star': '15.6k',
#   'Product URL': 'https://github.com/topics/flask?page=/jhao104/proxy_pool'},
#  {'Sr No': 5,
#   'User Name': 'Miserlou',
#   'Repository_Name': 'Zappa',
#   'Star': '11.9k',
#   'Product URL': 'https://github.com/topics/flask?page=/Miserlou/Zappa'},
#  {'Sr No': 6,
#   'User Name': 'humiaozuzu',
#   'Repository_Name': 'awesome-flask',
#   'Star': '10.7k',
#   'Product URL': 'https://github.com/topics/flask?page=/humiaozuzu/awesome-flask'},
#  {'Sr No': 7,
#   'User Name': 'miguelgrinberg',
#   'Repository_Name': 'flasky',
#   'Star': '7.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/miguelgrinberg/flasky'},
#  {'Sr No': 8,
#   'User Name': 'jofpin',
#   'Repository_Name': 'trape',
#   'Star': '7.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/jofpin/trape'},
#  {'Sr No': 9,
#   'User Name': 'dvf',
#   'Repository_Name': 'blockchain',
#   'Star': '7k',
#   'Product URL': 'https://github.com/topics/flask?page=/dvf/blockchain'},
#  {'Sr No': 10,
#   'User Name': 'pyeve',
#   'Repository_Name': 'eve',
#   'Star': '6.5k',
#   'Product URL': 'https://github.com/topics/flask?page=/pyeve/eve'},
#  {'Sr No': 11,
#   'User Name': 'benbusby',
#   'Repository_Name': 'whoogle-search',
#   'Star': '5.9k',
#   'Product URL': 'https://github.com/topics/flask?page=/benbusby/whoogle-search'},
#  {'Sr No': 12,
#   'User Name': 'joeyespo',
#   'Repository_Name': 'grip',
#   'Star': '5.7k',
#   'Product URL': 'https://github.com/topics/flask?page=/joeyespo/grip'},
#  {'Sr No': 13,
#   'User Name': 'miguelgrinberg',
#   'Repository_Name': 'Flask-SocketIO',
#   'Star': '4.7k',
#   'Product URL': 'https://github.com/topics/flask?page=/miguelgrinberg/Flask-SocketIO'},
#  {'Sr No': 14,
#   'User Name': 'schenkd',
#   'Repository_Name': 'nginx-ui',
#   'Star': '4.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/schenkd/nginx-ui'},
#  {'Sr No': 15,
#   'User Name': 'cookiecutter-flask',
#   'Repository_Name': 'cookiecutter-flask',
#   'Star': '4.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/cookiecutter-flask/cookiecutter-flask'},
#  {'Sr No': 16,
#   'User Name': 'CTFd',
#   'Repository_Name': 'CTFd',
#   'Star': '4.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/CTFd/CTFd'},
#  {'Sr No': 17,
#   'User Name': 'miguelgrinberg',
#   'Repository_Name': 'microblog',
#   'Star': '4k',
#   'Product URL': 'https://github.com/topics/flask?page=/miguelgrinberg/microblog'},
#  {'Sr No': 18,
#   'User Name': 'dpgaspar',
#   'Repository_Name': 'Flask-AppBuilder',
#   'Star': '3.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/dpgaspar/Flask-AppBuilder'},
#  {'Sr No': 19,
#   'User Name': 'pallets-eco',
#   'Repository_Name': 'flask-sqlalchemy',
#   'Star': '3.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/pallets-eco/flask-sqlalchemy'},
#  {'Sr No': 20,
#   'User Name': 'Python3WebSpider',
#   'Repository_Name': 'ProxyPool',
#   'Star': '3.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/Python3WebSpider/ProxyPool'},
#  {'Sr No': 21,
#   'User Name': 'taoufik07',
#   'Repository_Name': 'responder',
#   'Star': '3.6k',
#   'Product URL': 'https://github.com/topics/flask?page=/taoufik07/responder'},
#  {'Sr No': 22,
#   'User Name': 'man-group',
#   'Repository_Name': 'dtale',
#   'Star': '3.5k',
#   'Product URL': 'https://github.com/topics/flask?page=/man-group/dtale'},
#  {'Sr No': 23,
#   'User Name': 'ahkarami',
#   'Repository_Name': 'Deep-Learning-in-Production',
#   'Star': '3.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/ahkarami/Deep-Learning-in-Production'},
#  {'Sr No': 24,
#   'User Name': 'gaojiuli',
#   'Repository_Name': 'toapi',
#   'Star': '3.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/gaojiuli/toapi'},
#  {'Sr No': 25,
#   'User Name': 'christabor',
#   'Repository_Name': 'flask_jsondash',
#   'Star': '3.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/christabor/flask_jsondash'},
#  {'Sr No': 26,
#   'User Name': 'lepture',
#   'Repository_Name': 'authlib',
#   'Star': '3.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/lepture/authlib'},
#  {'Sr No': 27,
#   'User Name': 'the0demiurge',
#   'Repository_Name': 'ShadowSocksShare',
#   'Star': '3.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/the0demiurge/ShadowSocksShare'},
#  {'Sr No': 28,
#   'User Name': 'flasgger',
#   'Repository_Name': 'flasgger',
#   'Star': '3k',
#   'Product URL': 'https://github.com/topics/flask?page=/flasgger/flasgger'},
#  {'Sr No': 29,
#   'User Name': 'nyaadevs',
#   'Repository_Name': 'nyaa',
#   'Star': '3k',
#   'Product URL': 'https://github.com/topics/flask?page=/nyaadevs/nyaa'},
#  {'Sr No': 30,
#   'User Name': 'formspree',
#   'Repository_Name': 'formspree',
#   'Star': '2.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/formspree/formspree'},
#  {'Sr No': 31,
#   'User Name': 'hack4impact',
#   'Repository_Name': 'flask-base',
#   'Star': '2.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/hack4impact/flask-base'},
#  {'Sr No': 32,
#   'User Name': 'WhaleFell',
#   'Repository_Name': 'SMSBoom',
#   'Star': '2.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/WhaleFell/SMSBoom'},
#  {'Sr No': 33,
#   'User Name': 'tiangolo',
#   'Repository_Name': 'uwsgi-nginx-flask-docker',
#   'Star': '2.7k',
#   'Product URL': 'https://github.com/topics/flask?page=/tiangolo/uwsgi-nginx-flask-docker'},
#  {'Sr No': 34,
#   'User Name': 'noirbizarre',
#   'Repository_Name': 'flask-restplus',
#   'Star': '2.6k',
#   'Product URL': 'https://github.com/topics/flask?page=/noirbizarre/flask-restplus'},
#  {'Sr No': 35,
#   'User Name': 'simple-login',
#   'Repository_Name': 'app',
#   'Star': '2.6k',
#   'Product URL': 'https://github.com/topics/flask?page=/simple-login/app'},
#  {'Sr No': 36,
#   'User Name': 'rochacbruno',
#   'Repository_Name': 'dynaconf',
#   'Star': '2.5k',
#   'Product URL': 'https://github.com/topics/flask?page=/rochacbruno/dynaconf'},
#  {'Sr No': 37,
#   'User Name': 'tirthajyoti',
#   'Repository_Name': 'Machine-Learning-with-Python',
#   'Star': '2.4k',
#   'Product URL': 'https://github.com/topics/flask?page=/tirthajyoti/Machine-Learning-with-Python'},
#  {'Sr No': 38,
#   'User Name': 'flaskbb',
#   'Repository_Name': 'flaskbb',
#   'Star': '2.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/flaskbb/flaskbb'},
#  {'Sr No': 39,
#   'User Name': 'quokkaproject',
#   'Repository_Name': 'quokka',
#   'Star': '2.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/quokkaproject/quokka'},
#  {'Sr No': 40,
#   'User Name': 'ets-labs',
#   'Repository_Name': 'python-dependency-injector',
#   'Star': '2.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/ets-labs/python-dependency-injector'},
#  {'Sr No': 41,
#   'User Name': 'mjhea0',
#   'Repository_Name': 'flaskr-tdd',
#   'Star': '2.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/mjhea0/flaskr-tdd'},
#  {'Sr No': 42,
#   'User Name': 'python-security',
#   'Repository_Name': 'pyt',
#   'Star': '2.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/python-security/pyt'},
#  {'Sr No': 43,
#   'User Name': 'miguelgrinberg',
#   'Repository_Name': 'Flask-Migrate',
#   'Star': '2.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/miguelgrinberg/Flask-Migrate'},
#  {'Sr No': 44,
#   'User Name': 'johnwheeler',
#   'Repository_Name': 'flask-ask',
#   'Star': '1.9k',
#   'Product URL': 'https://github.com/topics/flask?page=/johnwheeler/flask-ask'},
#  {'Sr No': 45,
#   'User Name': 'codingforentrepreneurs',
#   'Repository_Name': '30-Days-of-Python',
#   'Star': '1.9k',
#   'Product URL': 'https://github.com/topics/flask?page=/codingforentrepreneurs/30-Days-of-Python'},
#  {'Sr No': 46,
#   'User Name': 'SelfhostedPro',
#   'Repository_Name': 'Yacht',
#   'Star': '1.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/SelfhostedPro/Yacht'},
#  {'Sr No': 47,
#   'User Name': 'dongweiming',
#   'Repository_Name': 'wechat-admin',
#   'Star': '1.7k',
#   'Product URL': 'https://github.com/topics/flask?page=/dongweiming/wechat-admin'},
#  {'Sr No': 48,
#   'User Name': 'rpicard',
#   'Repository_Name': 'explore-flask',
#   'Star': '1.6k',
#   'Product URL': 'https://github.com/topics/flask?page=/rpicard/explore-flask'},
#  {'Sr No': 49,
#   'User Name': 'ml-tooling',
#   'Repository_Name': 'best-of-web-python',
#   'Star': '1.6k',
#   'Product URL': 'https://github.com/topics/flask?page=/ml-tooling/best-of-web-python'},
#  {'Sr No': 50,
#   'User Name': 'python-restx',
#   'Repository_Name': 'flask-restx',
#   'Star': '1.6k',
#   'Product URL': 'https://github.com/topics/flask?page=/python-restx/flask-restx'},
#  {'Sr No': 51,
#   'User Name': 'zappa',
#   'Repository_Name': 'Zappa',
#   'Star': '1.8k',
#   'Product URL': 'https://github.com/topics/flask?page=/zappa/Zappa'},
#  {'Sr No': 52,
#   'User Name': 'coleifer',
#   'Repository_Name': 'sqlite-web',
#   'Star': '1.5k',
#   'Product URL': 'https://github.com/topics/flask?page=/coleifer/sqlite-web'},
#  {'Sr No': 53,
#   'User Name': 'abbeyokgo',
#   'Repository_Name': 'PyOne',
#   'Star': '1.5k',
#   'Product URL': 'https://github.com/topics/flask?page=/abbeyokgo/PyOne'},
#  {'Sr No': 54,
#   'User Name': 'dternyak',
#   'Repository_Name': 'React-Redux-Flask',
#   'Star': '1.4k',
#   'Product URL': 'https://github.com/topics/flask?page=/dternyak/React-Redux-Flask'},
#  {'Sr No': 55,
#   'User Name': 'lepture',
#   'Repository_Name': 'flask-oauthlib',
#   'Star': '1.4k',
#   'Product URL': 'https://github.com/topics/flask?page=/lepture/flask-oauthlib'},
#  {'Sr No': 56,
#   'User Name': 'greyli',
#   'Repository_Name': 'helloflask',
#   'Star': '1.4k',
#   'Product URL': 'https://github.com/topics/flask?page=/greyli/helloflask'},
#  {'Sr No': 57,
#   'User Name': 'indico',
#   'Repository_Name': 'indico',
#   'Star': '1.4k',
#   'Product URL': 'https://github.com/topics/flask?page=/indico/indico'},
#  {'Sr No': 58,
#   'User Name': 'paicha',
#   'Repository_Name': 'gxgk-wechat-server',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/paicha/gxgk-wechat-server'},
#  {'Sr No': 59,
#   'User Name': 'vimalloc',
#   'Repository_Name': 'flask-jwt-extended',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/vimalloc/flask-jwt-extended'},
#  {'Sr No': 60,
#   'User Name': 'zwczou',
#   'Repository_Name': 'weixin-python',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/zwczou/weixin-python'},
#  {'Sr No': 61,
#   'User Name': 'frol',
#   'Repository_Name': 'flask-restplus-server-example',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/frol/flask-restplus-server-example'},
#  {'Sr No': 62,
#   'User Name': 'wtforms',
#   'Repository_Name': 'flask-wtf',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/wtforms/flask-wtf'},
#  {'Sr No': 63,
#   'User Name': 'graphql-python',
#   'Repository_Name': 'flask-graphql',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/graphql-python/flask-graphql'},
#  {'Sr No': 64,
#   'User Name': 'marshmallow-code',
#   'Repository_Name': 'webargs',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/marshmallow-code/webargs'},
#  {'Sr No': 65,
#   'User Name': 'reloadware',
#   'Repository_Name': 'reloadium',
#   'Star': '1.3k',
#   'Product URL': 'https://github.com/topics/flask?page=/reloadware/reloadium'},
#  {'Sr No': 66,
#   'User Name': 'gtalarico',
#   'Repository_Name': 'flask-vuejs-template',
#   'Star': '1.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/gtalarico/flask-vuejs-template'},
#  {'Sr No': 67,
#   'User Name': 'pallets',
#   'Repository_Name': 'flask-website',
#   'Star': '1.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/pallets/flask-website'},
#  {'Sr No': 68,
#   'User Name': 'pinterest',
#   'Repository_Name': 'querybook',
#   'Star': '1.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/pinterest/querybook'},
#  {'Sr No': 69,
#   'User Name': 'dongweiming',
#   'Repository_Name': 'web_develop',
#   'Star': '1.2k',
#   'Product URL': 'https://github.com/topics/flask?page=/dongweiming/web_develop'},
#  {'Sr No': 70,
#   'User Name': 'burness',
#   'Repository_Name': 'tensorflow-101',
#   'Star': '1.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/burness/tensorflow-101'},
#  {'Sr No': 71,
#   'User Name': 'miguelgrinberg',
#   'Repository_Name': 'Flask-HTTPAuth',
#   'Star': '1.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/miguelgrinberg/Flask-HTTPAuth'},
#  {'Sr No': 72,
#   'User Name': 'guanshuicheng',
#   'Repository_Name': 'invoice',
#   'Star': '1.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/guanshuicheng/invoice'},
#  {'Sr No': 73,
#   'User Name': 'ai-eks',
#   'Repository_Name': 'OpenClubhouse',
#   'Star': '1.1k',
#   'Product URL': 'https://github.com/topics/flask?page=/ai-eks/OpenClubhouse'},
#  {'Sr No': 74,
#   'User Name': 'imfing',
#   'Repository_Name': 'keras-flask-deploy-webapp',
#   'Star': '1k',
#   'Product URL': 'https://github.com/topics/flask?page=/imfing/keras-flask-deploy-webapp'},
#  {'Sr No': 75,
#   'User Name': 'marshmallow-code',
#   'Repository_Name': 'apispec',
#   'Star': '965',
#   'Product URL': 'https://github.com/topics/flask?page=/marshmallow-code/apispec'},
#  {'Sr No': 76,
#   'User Name': 'QIN2DIM',
#   'Repository_Name': 'V2RayCloudSpider',
#   'Star': '970',
#   'Product URL': 'https://github.com/topics/flask?page=/QIN2DIM/V2RayCloudSpider'},
#  {'Sr No': 77,
#   'User Name': 'heroku',
#   'Repository_Name': 'heroku-buildpack-python',
#   'Star': '928',
#   'Product URL': 'https://github.com/topics/flask?page=/heroku/heroku-buildpack-python'},
#  {'Sr No': 78,
#   'User Name': 'cburmeister',
#   'Repository_Name': 'flask-bones',
#   'Star': '939',
#   'Product URL': 'https://github.com/topics/flask?page=/cburmeister/flask-bones'},
#  {'Sr No': 79,
#   'User Name': 'mjhea0',
#   'Repository_Name': 'awesome-flask',
#   'Star': '937',
#   'Product URL': 'https://github.com/topics/flask?page=/mjhea0/awesome-flask'},
#  {'Sr No': 80,
#   'User Name': 'lxztju',
#   'Repository_Name': 'pytorch_classification',
#   'Star': '925',
#   'Product URL': 'https://github.com/topics/flask?page=/lxztju/pytorch_classification'},
#  {'Sr No': 81,
#   'User Name': 'rwv',
#   'Repository_Name': 'chinese-dos-games-web',
#   'Star': '946',
#   'Product URL': 'https://github.com/topics/flask?page=/rwv/chinese-dos-games-web'},
#  {'Sr No': 82,
#   'User Name': 'seasonstar',
#   'Repository_Name': 'bibi',
#   'Star': '911',
#   'Product URL': 'https://github.com/topics/flask?page=/seasonstar/bibi'},
#  {'Sr No': 83,
#   'User Name': 'viniciuschiele',
#   'Repository_Name': 'flask-apscheduler',
#   'Star': '917',
#   'Product URL': 'https://github.com/topics/flask?page=/viniciuschiele/flask-apscheduler'},
#  {'Sr No': 84,
#   'User Name': 'tecladocode',
#   'Repository_Name': 'rest-apis-flask-python',
#   'Star': '917',
#   'Product URL': 'https://github.com/topics/flask?page=/tecladocode/rest-apis-flask-python'},
#  {'Sr No': 85,
#   'User Name': 'Leo-G',
#   'Repository_Name': 'Flask-Scaffold',
#   'Star': '879',
#   'Product URL': 'https://github.com/topics/flask?page=/Leo-G/Flask-Scaffold'},
#  {'Sr No': 86,
#   'User Name': 'ByronHsu',
#   'Repository_Name': 'Never-Blink',
#   'Star': '852',
#   'Product URL': 'https://github.com/topics/flask?page=/ByronHsu/Never-Blink'},
#  {'Sr No': 87,
#   'User Name': 'HaoZhang95',
#   'Repository_Name': 'Python24',
#   'Star': '901',
#   'Product URL': 'https://github.com/topics/flask?page=/HaoZhang95/Python24'},
#  {'Sr No': 88,
#   'User Name': 'clarketm',
#   'Repository_Name': 'TableExport',
#   'Star': '836',
#   'Product URL': 'https://github.com/topics/flask?page=/clarketm/TableExport'},
#  {'Sr No': 89,
#   'User Name': 'toastdriven',
#   'Repository_Name': 'restless',
#   'Star': '824',
#   'Product URL': 'https://github.com/topics/flask?page=/toastdriven/restless'},
#  {'Sr No': 90,
#   'User Name': 'klen',
#   'Repository_Name': 'mixer',
#   'Star': '836',
#   'Product URL': 'https://github.com/topics/flask?page=/klen/mixer'},
#  {'Sr No': 91,
#   'User Name': 'nickjj',
#   'Repository_Name': 'build-a-saas-app-with-flask',
#   'Star': '821',
#   'Product URL': 'https://github.com/topics/flask?page=/nickjj/build-a-saas-app-with-flask'},
#  {'Sr No': 92,
#   'User Name': 'MongoEngine',
#   'Repository_Name': 'flask-mongoengine',
#   'Star': '802',
#   'Product URL': 'https://github.com/topics/flask?page=/MongoEngine/flask-mongoengine'},
#  {'Sr No': 93,
#   'User Name': 'wylok',
#   'Repository_Name': 'sparrow',
#   'Star': '807',
#   'Product URL': 'https://github.com/topics/flask?page=/wylok/sparrow'},
#  {'Sr No': 94,
#   'User Name': 'jadianes',
#   'Repository_Name': 'spark-movie-lens',
#   'Star': '788',
#   'Product URL': 'https://github.com/topics/flask?page=/jadianes/spark-movie-lens'},
#  {'Sr No': 95,
#   'User Name': 'coleifer',
#   'Repository_Name': 'flask-peewee',
#   'Star': '752',
#   'Product URL': 'https://github.com/topics/flask?page=/coleifer/flask-peewee'},
#  {'Sr No': 96,
#   'User Name': 'marshmallow-code',
#   'Repository_Name': 'flask-marshmallow',
#   'Star': '747',
#   'Product URL': 'https://github.com/topics/flask?page=/marshmallow-code/flask-marshmallow'},
#  {'Sr No': 97,
#   'User Name': 'Baiyuetribe',
#   'Repository_Name': 'kamiFaka',
#   'Star': '752',
#   'Product URL': 'https://github.com/topics/flask?page=/Baiyuetribe/kamiFaka'},
#  {'Sr No': 98,
#   'User Name': 'jwkvam',
#   'Repository_Name': 'bowtie',
#   'Star': '749',
#   'Product URL': 'https://github.com/topics/flask?page=/jwkvam/bowtie'},
#  {'Sr No': 99,
#   'User Name': 'spiral-project',
#   'Repository_Name': 'ihatemoney',
#   'Star': '746',
#   'Product URL': 'https://github.com/topics/flask?page=/spiral-project/ihatemoney'},
#  {'Sr No': 100,
#   'User Name': 'anfederico',
#   'Repository_Name': 'flaskex',
#   'Star': '737',
#   'Product URL': 'https://github.com/topics/flask?page=/anfederico/flaskex'},
#  {'Sr No': 101,
#   'User Name': '521xueweihan',
#   'Repository_Name': 'hellogithub.com',
#   'Star': '725',
#   'Product URL': 'https://github.com/topics/flask?page=/521xueweihan/hellogithub.com'},
#  {'Sr No': 102,
#   'User Name': 'TaleLin',
#   'Repository_Name': 'lin-cms-flask',
#   'Star': '724',
#   'Product URL': 'https://github.com/topics/flask?page=/TaleLin/lin-cms-flask'},
#  {'Sr No': 103,
#   'User Name': 'pallets-eco',
#   'Repository_Name': 'flask-caching',
#   'Star': '726',
#   'Product URL': 'https://github.com/topics/flask?page=/pallets-eco/flask-caching'},
#  {'Sr No': 104,
#   'User Name': 'Frozen-Flask',
#   'Repository_Name': 'Frozen-Flask',
#   'Star': '719',
#   'Product URL': 'https://github.com/topics/flask?page=/Frozen-Flask/Frozen-Flask'},
#  {'Sr No': 105,
#   'User Name': 'helloflask',
#   'Repository_Name': 'bootstrap-flask',
#   'Star': '712',
#   'Product URL': 'https://github.com/topics/flask?page=/helloflask/bootstrap-flask'},
#  {'Sr No': 106,
#   'User Name': 'mher',
#   'Repository_Name': 'chartkick.py',
#   'Star': '693',
#   'Product URL': 'https://github.com/topics/flask?page=/mher/chartkick.py'},
#  {'Sr No': 107,
#   'User Name': 'zenodo',
#   'Repository_Name': 'zenodo',
#   'Star': '693',
#   'Product URL': 'https://github.com/topics/flask?page=/zenodo/zenodo'},
#  {'Sr No': 108,
#   'User Name': 'coto',
#   'Repository_Name': 'gae-boilerplate',
#   'Star': '689',
#   'Product URL': 'https://github.com/topics/flask?page=/coto/gae-boilerplate'},
#  {'Sr No': 109,
#   'User Name': 'karec',
#   'Repository_Name': 'cookiecutter-flask-restful',
#   'Star': '697',
#   'Product URL': 'https://github.com/topics/flask?page=/karec/cookiecutter-flask-restful'},
#  {'Sr No': 110,
#   'User Name': 'muatik',
#   'Repository_Name': 'flask-profiler',
#   'Star': '695',
#   'Product URL': 'https://github.com/topics/flask?page=/muatik/flask-profiler'},
#  {'Sr No': 111,
#   'User Name': 'wangy8961',
#   'Repository_Name': 'flask-vuejs-madblog',
#   'Star': '688',
#   'Product URL': 'https://github.com/topics/flask?page=/wangy8961/flask-vuejs-madblog'},
#  {'Sr No': 112,
#   'User Name': 'LeonLok',
#   'Repository_Name': 'Multi-Camera-Live-Object-Tracking',
#   'Star': '669',
#   'Product URL': 'https://github.com/topics/flask?page=/LeonLok/Multi-Camera-Live-Object-Tracking'},
#  {'Sr No': 113,
#   'User Name': 'saasforge',
#   'Repository_Name': 'open-source-saas-boilerpate',
#   'Star': '666',
#   'Product URL': 'https://github.com/topics/flask?page=/saasforge/open-source-saas-boilerpate'},
#  {'Sr No': 114,
#   'User Name': 'liwanlei',
#   'Repository_Name': 'FXTest',
#   'Star': '664',
#   'Product URL': 'https://github.com/topics/flask?page=/liwanlei/FXTest'},
#  {'Sr No': 115,
#   'User Name': 'rantav',
#   'Repository_Name': 'flask-restful-swagger',
#   'Star': '653',
#   'Product URL': 'https://github.com/topics/flask?page=/rantav/flask-restful-swagger'},
#  {'Sr No': 116,
#   'User Name': 'MLH',
#   'Repository_Name': 'mlh-hackathon-flask-starter',
#   'Star': '651',
#   'Product URL': 'https://github.com/topics/flask?page=/MLH/mlh-hackathon-flask-starter'},
#  {'Sr No': 117,
#   'User Name': 'gouthambs',
#   'Repository_Name': 'Flask-Blogging',
#   'Star': '647',
#   'Product URL': 'https://github.com/topics/flask?page=/gouthambs/Flask-Blogging'},
#  {'Sr No': 118,
#   'User Name': 'italomaia',
#   'Repository_Name': 'flask-empty',
#   'Star': '624',
#   'Product URL': 'https://github.com/topics/flask?page=/italomaia/flask-empty'},
#  {'Sr No': 119,
#   'User Name': 'flask-dashboard',
#   'Repository_Name': 'Flask-MonitoringDashboard',
#   'Star': '631',
#   'Product URL': 'https://github.com/topics/flask?page=/flask-dashboard/Flask-MonitoringDashboard'},
#  {'Sr No': 120,
#   'User Name': 'qzq1111',
#   'Repository_Name': 'flask-restful-example',
#   'Star': '639',
#   'Product URL': 'https://github.com/topics/flask?page=/qzq1111/flask-restful-example'},
#  {'Sr No': 121,
#   'User Name': 'cak',
#   'Repository_Name': 'secure',
#   'Star': '622',
#   'Product URL': 'https://github.com/topics/flask?page=/cak/secure'},
#  {'Sr No': 122,
#   'User Name': 'apiflask',
#   'Repository_Name': 'apiflask',
#   'Star': '600',
#   'Product URL': 'https://github.com/topics/flask?page=/apiflask/apiflask'},
#  {'Sr No': 123,
#   'User Name': 'miLibris',
#   'Repository_Name': 'flask-rest-jsonapi',
#   'Star': '597',
#   'Product URL': 'https://github.com/topics/flask?page=/miLibris/flask-rest-jsonapi'},
#  {'Sr No': 124,
#   'User Name': 'enginebai',
#   'Repository_Name': 'PyMessager',
#   'Star': '592',
#   'Product URL': 'https://github.com/topics/flask?page=/enginebai/PyMessager'},
#  {'Sr No': 125,
#   'User Name': 'flask-extensions',
#   'Repository_Name': 'Flask-GoogleMaps',
#   'Star': '597',
#   'Product URL': 'https://github.com/topics/flask?page=/flask-extensions/Flask-GoogleMaps'},
#  {'Sr No': 126,
#   'User Name': 'testdrivenio',
#   'Repository_Name': 'flask-vue-crud',
#   'Star': '614',
#   'Product URL': 'https://github.com/topics/flask?page=/testdrivenio/flask-vue-crud'},
#  {'Sr No': 127,
#   'User Name': 'amitt001',
#   'Repository_Name': 'pygmy',
#   'Star': '585',
#   'Product URL': 'https://github.com/topics/flask?page=/amitt001/pygmy'},
#  {'Sr No': 128,
#   'User Name': 'cosmic-byte',
#   'Repository_Name': 'flask-restplus-boilerplate',
#   'Star': '592',
#   'Product URL': 'https://github.com/topics/flask?page=/cosmic-byte/flask-restplus-boilerplate'},
#  {'Sr No': 129,
#   'User Name': 'slackapi',
#   'Repository_Name': 'bolt-python',
#   'Star': '571',
#   'Product URL': 'https://github.com/topics/flask?page=/slackapi/bolt-python'},
#  {'Sr No': 130,
#   'User Name': 'ssola',
#   'Repository_Name': 'python-flask-microservice',
#   'Star': '569',
#   'Product URL': 'https://github.com/topics/flask?page=/ssola/python-flask-microservice'},
#  {'Sr No': 131,
#   'User Name': 'DjangoEx',
#   'Repository_Name': 'python-engineer-roadmap',
#   'Star': '567',
#   'Product URL': 'https://github.com/topics/flask?page=/DjangoEx/python-engineer-roadmap'},
#  {'Sr No': 132,
#   'User Name': 'lxc-webpanel',
#   'Repository_Name': 'LXC-Web-Panel',
#   'Star': '563',
#   'Product URL': 'https://github.com/topics/flask?page=/lxc-webpanel/LXC-Web-Panel'},
#  {'Sr No': 133,
#   'User Name': 'osroom',
#   'Repository_Name': 'osroom',
#   'Star': '562',
#   'Product URL': 'https://github.com/topics/flask?page=/osroom/osroom'},
#  {'Sr No': 134,
#   'User Name': 'matsui528',
#   'Repository_Name': 'sis',
#   'Star': '596',
#   'Product URL': 'https://github.com/topics/flask?page=/matsui528/sis'},
#  {'Sr No': 135,
#   'User Name': 'psincraian',
#   'Repository_Name': 'pepy',
#   'Star': '592',
#   'Product URL': 'https://github.com/topics/flask?page=/psincraian/pepy'},
#  {'Sr No': 136,
#   'User Name': 'guokr',
#   'Repository_Name': 'swagger-py-codegen',
#   'Star': '546',
#   'Product URL': 'https://github.com/topics/flask?page=/guokr/swagger-py-codegen'},
#  {'Sr No': 137,
#   'User Name': 'rochacbruno',
#   'Repository_Name': 'python-project-template',
#   'Star': '550',
#   'Product URL': 'https://github.com/topics/flask?page=/rochacbruno/python-project-template'},
#  {'Sr No': 138,
#   'User Name': 'afourmy',
#   'Repository_Name': 'flask-gentelella',
#   'Star': '551',
#   'Product URL': 'https://github.com/topics/flask?page=/afourmy/flask-gentelella'},
#  {'Sr No': 139,
#   'User Name': 'gae-init',
#   'Repository_Name': 'gae-init',
#   'Star': '534',
#   'Product URL': 'https://github.com/topics/flask?page=/gae-init/gae-init'},
#  {'Sr No': 140,
#   'User Name': 'Allen7D',
#   'Repository_Name': 'mini-shop-server',
#   'Star': '543',
#   'Product URL': 'https://github.com/topics/flask?page=/Allen7D/mini-shop-server'},
#  {'Sr No': 141,
#   'User Name': 'inveniosoftware',
#   'Repository_Name': 'invenio',
#   'Star': '535',
#   'Product URL': 'https://github.com/topics/flask?page=/inveniosoftware/invenio'},
#  {'Sr No': 142,
#   'User Name': 'helloflask',
#   'Repository_Name': 'flask-tutorial',
#   'Star': '544',
#   'Product URL': 'https://github.com/topics/flask?page=/helloflask/flask-tutorial'},
#  {'Sr No': 143,
#   'User Name': 'gamegos',
#   'Repository_Name': 'cesi',
#   'Star': '531',
#   'Product URL': 'https://github.com/topics/flask?page=/gamegos/cesi'},
#  {'Sr No': 144,
#   'User Name': 'jerrylizilong',
#   'Repository_Name': 'autotest_platform',
#   'Star': '521',
#   'Product URL': 'https://github.com/topics/flask?page=/jerrylizilong/autotest_platform'},
#  {'Sr No': 145,
#   'User Name': 'rnevius',
#   'Repository_Name': 'minimal-django',
#   'Star': '519',
#   'Product URL': 'https://github.com/topics/flask?page=/rnevius/minimal-django'},
#  {'Sr No': 146,
#   'User Name': 'codelucas',
#   'Repository_Name': 'flask_reddit',
#   'Star': '509',
#   'Product URL': 'https://github.com/topics/flask?page=/codelucas/flask_reddit'},
#  {'Sr No': 147,
#   'User Name': 'cernopendata',
#   'Repository_Name': 'opendata.cern.ch',
#   'Star': '509',
#   'Product URL': 'https://github.com/topics/flask?page=/cernopendata/opendata.cern.ch'},
#  {'Sr No': 148,
#   'User Name': 'ptpb',
#   'Repository_Name': 'pb',
#   'Star': '501',
#   'Product URL': 'https://github.com/topics/flask?page=/ptpb/pb'},
#  {'Sr No': 149,
#   'User Name': 'm0ngr31',
#   'Repository_Name': 'DailyNotes',
#   'Star': '505',
#   'Product URL': 'https://github.com/topics/flask?page=/m0ngr31/DailyNotes'},
#  {'Sr No': 150,
#   'User Name': 'karpathy',
#   'Repository_Name': 'arxiv-sanity-lite',
#   'Star': '562',
#   'Product URL': 'https://github.com/topics/flask?page=/karpathy/arxiv-sanity-lite'},
#  {'Sr No': 151,
#   'User Name': 'chaijunit',
#   'Repository_Name': 'beibq',
#   'Star': '503',
#   'Product URL': 'https://github.com/topics/flask?page=/chaijunit/beibq'},
#  {'Sr No': 152,
#   'User Name': 'Maicius',
#   'Repository_Name': 'QQZoneMood',
#   'Star': '496',
#   'Product URL': 'https://github.com/topics/flask?page=/Maicius/QQZoneMood'},
#  {'Sr No': 153,
#   'User Name': 'tiangolo',
#   'Repository_Name': 'full-stack',
#   'Star': '501',
#   'Product URL': 'https://github.com/topics/flask?page=/tiangolo/full-stack'},
#  {'Sr No': 154,
#   'User Name': 'hhstore',
#   'Repository_Name': 'annotated-py-projects',
#   'Star': '515',
#   'Product URL': 'https://github.com/topics/flask?page=/hhstore/annotated-py-projects'},
#  {'Sr No': 155,
#   'User Name': 'alectrocute',
#   'Repository_Name': 'flaskSaaS',
#   'Star': '508',
#   'Product URL': 'https://github.com/topics/flask?page=/alectrocute/flaskSaaS'},
#  {'Sr No': 156,
#   'User Name': 'miguelgrinberg',
#   'Repository_Name': 'flack',
#   'Star': '491',
#   'Product URL': 'https://github.com/topics/flask?page=/miguelgrinberg/flack'},
#  {'Sr No': 157,
#   'User Name': 'biosustain',
#   'Repository_Name': 'potion',
#   'Star': '487',
#   'Product URL': 'https://github.com/topics/flask?page=/biosustain/potion'},
#  {'Sr No': 158,
#   'User Name': 'talkpython',
#   'Repository_Name': 'data-driven-web-apps-with-flask',
#   'Star': '482',
#   'Product URL': 'https://github.com/topics/flask?page=/talkpython/data-driven-web-apps-with-flask'},
#  {'Sr No': 159,
#   'User Name': 'fabston',
#   'Repository_Name': 'TradingView-Webhook-Bot',
#   'Star': '566',
#   'Product URL': 'https://github.com/topics/flask?page=/fabston/TradingView-Webhook-Bot'},
#  {'Sr No': 160,
#   'User Name': 'ytorg',
#   'Repository_Name': 'Yotter',
#   'Star': '472',
#   'Product URL': 'https://github.com/topics/flask?page=/ytorg/Yotter'},
#  {'Sr No': 161,
#   'User Name': 'rycus86',
#   'Repository_Name': 'prometheus_flask_exporter',
#   'Star': '485',
#   'Product URL': 'https://github.com/topics/flask?page=/rycus86/prometheus_flask_exporter'},
#  {'Sr No': 162,
#   'User Name': 'marshmallow-code',
#   'Repository_Name': 'flask-smorest',
#   'Star': '465',
#   'Product URL': 'https://github.com/topics/flask?page=/marshmallow-code/flask-smorest'},
#  {'Sr No': 163,
#   'User Name': 'pycook',
#   'Repository_Name': 'cmdb',
#   'Star': '445',
#   'Product URL': 'https://github.com/topics/flask?page=/pycook/cmdb'},
#  {'Sr No': 164,
#   'User Name': 'honmaple',
#   'Repository_Name': 'maple-bbs',
#   'Star': '445',
#   'Product URL': 'https://github.com/topics/flask?page=/honmaple/maple-bbs'},
#  {'Sr No': 165,
#   'User Name': 'logandk',
#   'Repository_Name': 'serverless-wsgi',
#   'Star': '433',
#   'Product URL': 'https://github.com/topics/flask?page=/logandk/serverless-wsgi'},
#  {'Sr No': 166,
#   'User Name': 'flyhigher139',
#   'Repository_Name': 'OctBlog',
#   'Star': '430',
#   'Product URL': 'https://github.com/topics/flask?page=/flyhigher139/OctBlog'},
#  {'Sr No': 167,
#   'User Name': 'Evil0ctal',
#   'Repository_Name': 'Douyin_TikTok_Download_API',
#   'Star': '442',
#   'Product URL': 'https://github.com/topics/flask?page=/Evil0ctal/Douyin_TikTok_Download_API'},
#  {'Sr No': 168,
#   'User Name': 'pytest-dev',
#   'Repository_Name': 'pytest-flask',
#   'Star': '423',
#   'Product URL': 'https://github.com/topics/flask?page=/pytest-dev/pytest-flask'},
#  {'Sr No': 169,
#   'User Name': 'Flask-Middleware',
#   'Repository_Name': 'flask-security',
#   'Star': '423',
#   'Product URL': 'https://github.com/topics/flask?page=/Flask-Middleware/flask-security'},
#  {'Sr No': 170,
#   'User Name': 'smoqadam',
#   'Repository_Name': 'PyFladesk',
#   'Star': '424',
#   'Product URL': 'https://github.com/topics/flask?page=/smoqadam/PyFladesk'},
#  {'Sr No': 171,
#   'User Name': 'tiangolo',
#   'Repository_Name': 'meinheld-gunicorn-flask-docker',
#   'Star': '428',
#   'Product URL': 'https://github.com/topics/flask?page=/tiangolo/meinheld-gunicorn-flask-docker'},
#  {'Sr No': 172,
#   'User Name': 'taosir',
#   'Repository_Name': 'cnn_handwritten_chinese_recognition',
#   'Star': '422',
#   'Product URL': 'https://github.com/topics/flask?page=/taosir/cnn_handwritten_chinese_recognition'},
#  {'Sr No': 173,
#   'User Name': 'level09',
#   'Repository_Name': 'enferno',
#   'Star': '406',
#   'Product URL': 'https://github.com/topics/flask?page=/level09/enferno'},
#  {'Sr No': 174,
#   'User Name': 'underyx',
#   'Repository_Name': 'flask-redis',
#   'Star': '407',
#   'Product URL': 'https://github.com/topics/flask?page=/underyx/flask-redis'},
#  {'Sr No': 175,
#   'User Name': 'toddbirchard',
#   'Repository_Name': 'plotlydash-flask-tutorial',
#   'Star': '406',
#   'Product URL': 'https://github.com/topics/flask?page=/toddbirchard/plotlydash-flask-tutorial'},
#  {'Sr No': 176,
#   'User Name': 'abbeyokgo',
#   'Repository_Name': 'ojbk_jiexi',
#   'Star': '395',
#   'Product URL': 'https://github.com/topics/flask?page=/abbeyokgo/ojbk_jiexi'},
#  {'Sr No': 177,
#   'User Name': 'hotosm',
#   'Repository_Name': 'tasking-manager',
#   'Star': '395',
#   'Product URL': 'https://github.com/topics/flask?page=/hotosm/tasking-manager'},
#  {'Sr No': 178,
#   'User Name': 'fengsp',
#   'Repository_Name': 'flask-session',
#   'Star': '395',
#   'Product URL': 'https://github.com/topics/flask?page=/fengsp/flask-session'},
#  {'Sr No': 179,
#   'User Name': 'yymm',
#   'Repository_Name': 'flask-vuejs',
#   'Star': '390',
#   'Product URL': 'https://github.com/topics/flask?page=/yymm/flask-vuejs'},
#  {'Sr No': 180,
#   'User Name': 'spacewander',
#   'Repository_Name': 'explore-flask-zh',
#   'Star': '388',
#   'Product URL': 'https://github.com/topics/flask?page=/spacewander/explore-flask-zh'},
#  {'Sr No': 181,
#   'User Name': 'Naresh1318',
#   'Repository_Name': 'Topaz',
#   'Star': '383',
#   'Product URL': 'https://github.com/topics/flask?page=/Naresh1318/Topaz'},
#  {'Sr No': 182,
#   'User Name': 'ibrahimirdem',
#   'Repository_Name': 'turkce-python-kaynaklari',
#   'Star': '382',
#   'Product URL': 'https://github.com/topics/flask?page=/ibrahimirdem/turkce-python-kaynaklari'},
#  {'Sr No': 183,
#   'User Name': 'noraj',
#   'Repository_Name': 'flask-session-cookie-manager',
#   'Star': '373',
#   'Product URL': 'https://github.com/topics/flask?page=/noraj/flask-session-cookie-manager'},
#  {'Sr No': 184,
#   'User Name': 'antkahn',
#   'Repository_Name': 'flask-api-starter-kit',
#   'Star': '378',
#   'Product URL': 'https://github.com/topics/flask?page=/antkahn/flask-api-starter-kit'},
#  {'Sr No': 185,
#   'User Name': 'elastic',
#   'Repository_Name': 'apm-agent-python',
#   'Star': '356',
#   'Product URL': 'https://github.com/topics/flask?page=/elastic/apm-agent-python'},
#  {'Sr No': 186,
#   'User Name': 'thomaxxl',
#   'Repository_Name': 'safrs',
#   'Star': '346',
#   'Product URL': 'https://github.com/topics/flask?page=/thomaxxl/safrs'},
#  {'Sr No': 187,
#   'User Name': 'cristianzsh',
#   'Repository_Name': 'freki',
#   'Star': '344',
#   'Product URL': 'https://github.com/topics/flask?page=/cristianzsh/freki'},
#  {'Sr No': 188,
#   'User Name': 'no13bus',
#   'Repository_Name': 'baymax',
#   'Star': '341',
#   'Product URL': 'https://github.com/topics/flask?page=/no13bus/baymax'},
#  {'Sr No': 189,
#   'User Name': 'jhao104',
#   'Repository_Name': 'SSDBAdmin',
#   'Star': '341',
#   'Product URL': 'https://github.com/topics/flask?page=/jhao104/SSDBAdmin'},
#  {'Sr No': 190,
#   'User Name': 'chamkank',
#   'Repository_Name': 'flask-chatterbot',
#   'Star': '348',
#   'Product URL': 'https://github.com/topics/flask?page=/chamkank/flask-chatterbot'},
#  {'Sr No': 191,
#   'User Name': 'controversial',
#   'Repository_Name': 'wikipedia-map',
#   'Star': '350',
#   'Product URL': 'https://github.com/topics/flask?page=/controversial/wikipedia-map'},
#  {'Sr No': 192,
#   'User Name': 'hackersandslackers',
#   'Repository_Name': 'flask-blueprint-tutorial',
#   'Star': '355',
#   'Product URL': 'https://github.com/topics/flask?page=/hackersandslackers/flask-blueprint-tutorial'},
#  {'Sr No': 193,
#   'User Name': 'damyanbogoev',
#   'Repository_Name': 'flask-bookshelf',
#   'Star': '336',
#   'Product URL': 'https://github.com/topics/flask?page=/damyanbogoev/flask-bookshelf'},
#  {'Sr No': 194,
#   'User Name': '01joy',
#   'Repository_Name': 'news-search-engine',
#   'Star': '357',
#   'Product URL': 'https://github.com/topics/flask?page=/01joy/news-search-engine'},
#  {'Sr No': 195,
#   'User Name': 'jamesroberts',
#   'Repository_Name': 'fastwsgi',
#   'Star': '333',
#   'Product URL': 'https://github.com/topics/flask?page=/jamesroberts/fastwsgi'},
#  {'Sr No': 196,
#   'User Name': 'app-generator',
#   'Repository_Name': 'admin-dashboards',
#   'Star': '334',
#   'Product URL': 'https://github.com/topics/flask?page=/app-generator/admin-dashboards'},
#  {'Sr No': 197,
#   'User Name': 'whusnoopy',
#   'Repository_Name': 'renrenBackup',
#   'Star': '335',
#   'Product URL': 'https://github.com/topics/flask?page=/whusnoopy/renrenBackup'},
#  {'Sr No': 198,
#   'User Name': 'NetEaseGame',
#   'Repository_Name': 'redis-monitor',
#   'Star': '329',
#   'Product URL': 'https://github.com/topics/flask?page=/NetEaseGame/redis-monitor'},
#  {'Sr No': 199,
#   'User Name': 'GOATS2K',
#   'Repository_Name': 'overpass',
#   'Star': '326',
#   'Product URL': 'https://github.com/topics/flask?page=/GOATS2K/overpass'},
#  {'Sr No': 200,
#   'User Name': 'hackersandslackers',
#   'Repository_Name': 'flask-sqlalchemy-tutorial',
#   'Star': '319',
#   'Product URL': 'https://github.com/topics/flask?page=/hackersandslackers/flask-sqlalchemy-tutorial'}]

# %%
import pandas as pd
final_data= pd.DataFrame(flask_lst)
final_data
# Out:
#      Sr No           User Name            Repository_Name   Star  \
# 0        1             pallets                      flask  59.7k
# 1        2              apache                   superset  46.9k
# 2        3              plotly                       dash  16.8k
# 3        4             jhao104                 proxy_pool  15.6k
# 4        5            Miserlou                      Zappa  11.9k
# ..     ...                 ...                        ...    ...
# 195    196       app-generator           admin-dashboards    334
# 196    197           whusnoopy               renrenBackup    335
# 197    198         NetEaseGame              redis-monitor    329
# 198    199             GOATS2K                   overpass    326
# 199    200  hackersandslackers  flask-sqlalchemy-tutorial    319
#
#                                            Product URL
# 0    https://github.com/topics/flask?page=/pallets/...
# 1    https://github.com/topics/flask?page=/apache/s...
# 2    https://github.com/topics/flask?page=/plotly/dash
# 3    https://github.com/topics/flask?page=/jhao104/...
# 4    https://github.com/topics/flask?page=/Miserlou...
# ..                                                 ...
# 195  https://github.com/topics/flask?page=/app-gene...
# 196  https://github.com/topics/flask?page=/whusnoop...
# 197  https://github.com/topics/flask?page=/NetEaseG...
# 198  https://github.com/topics/flask?page=/GOATS2K/...
# 199  https://github.com/topics/flask?page=/hackersa...
#
# [200 rows x 5 columns]

# %%
final_data.to_excel('flask_lst.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\Shraddha'
